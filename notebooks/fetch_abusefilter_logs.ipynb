# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook explains how to run the program to fetch abusefilter logs from Wikipedia API.

# %%
import requests
import pandas as pd

# %%
# append system path to import spider program
import sys
sys.path.append('../')
from utils.spider_abusefilter import retrieve_abusefilter_logs_month # fetch data for a specific month in a given year
from utils.spider_abusefilter import retrieve_abusefilter_logs_year # fetch data for a given year

# %% [markdown]
# # Code examples

# %% [markdown]
# ## Retrieve data for 1 month

# %% [markdown]
# To retrieve logs for a specific month, please use the retrieve_abusefilter_logs_month function. It automatically retrieves the logs and write them into a local csv file (format: year-month.csv).
#
# It requires 4 parameters:
# - request_session:
#     - A request session to sent API requests.
# - year (int):
#     - The year for which block logs should be retrieved.
# - month (int):
#     - The month for which block logs should be retrieved.
# - folder_path (str):
#     - The folder path where the CSV file will be saved.
#     - Example: './data/abusefilter_logs/'

# %% [markdown]
# **Note:**
# - No csv will be created, if 0 record is retrieved.
# - If you encounter issues at running the function, please check if a file already exists on your local disk. This function automatically stop to prevent from overwritting local file.

# %%
# Set folder path to store fetched data
folder_path = '../data/abusefilter_logs/'

# %%
s = requests.Session()
retrieve_abusefilter_logs_month(request_session=s, year=2008, month=2, folder_path=folder_path)
# Out:
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-02-01T00:00:00Z and 2008-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-02-01T00:00:00Z and 2008-03-01T00:00:00Z.
# No record was retrieved or saved.

# %% [markdown]
# ## Retrieve data for 1 year

# %% [markdown]
# To retrieve block logs for a specific year, please use the retrieve_abusefilter_logs_year function. It automatically loops over the month retrive function to download and store logs for a given year. The data will be stored in 12 local csv files (format: year-month.csv), each for 1 month.
#
# It requires 3 parameters:
# - request_session:
#     - A request session to sent API requests.
# - year (int):
#     - The year for which block logs should be retrieved.
# - folder_path (str):
#     - The folder path where the CSV file will be saved.

# %% [markdown]
# **Note:**
# - No csv will be created, if 0 record is retrieved.
# - The first abusefilter log was in March 2009.
# - If you encounter issues at running the function, please check if a file already exists on your local disk. This function automatically stop to prevent from overwritting local file.

# %%
# Set folder path to store fetched data
folder_path = '../data/abusefilter_logs/'
s = requests.Session()

# %%
for year in range(2008, 2024, 1):
    retrieve_abusefilter_logs_year(request_session=s, year=year, folder_path=folder_path)
# Out:
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-01-01T00:00:00Z and 2008-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-01-01T00:00:00Z and 2008-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-02-01T00:00:00Z and 2008-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-02-01T00:00:00Z and 2008-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-03-01T00:00:00Z and 2008-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-03-01T00:00:00Z and 2008-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-04-01T00:00:00Z and 2008-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-04-01T00:00:00Z and 2008-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-05-01T00:00:00Z and 2008-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-05-01T00:00:00Z and 2008-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-06-01T00:00:00Z and 2008-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-06-01T00:00:00Z and 2008-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-07-01T00:00:00Z and 2008-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-07-01T00:00:00Z and 2008-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-08-01T00:00:00Z and 2008-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-08-01T00:00:00Z and 2008-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-09-01T00:00:00Z and 2008-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-09-01T00:00:00Z and 2008-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-10-01T00:00:00Z and 2008-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-10-01T00:00:00Z and 2008-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-11-01T00:00:00Z and 2008-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-11-01T00:00:00Z and 2008-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2008-12-01T00:00:00Z and 2009-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2008-12-01T00:00:00Z and 2009-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2009-01-01T00:00:00Z and 2009-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-01-01T00:00:00Z and 2009-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 0 records retrieved.
# Retrieval complete for logs between 2009-02-01T00:00:00Z and 2009-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-02-01T00:00:00Z and 2009-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 500 records retrieved.
# Search with continue index: 20090319184403|68552949, 500 records retrieved.
# Search with continue index: 20090325094416|68553450, 281 records retrieved.
# Retrieval complete for logs between 2009-03-01T00:00:00Z and 2009-04-01T00:00:00Z.
# Total 1281 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-03-01T00:00:00Z and 2009-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 492 records retrieved.
# Retrieval complete for logs between 2009-04-01T00:00:00Z and 2009-05-01T00:00:00Z.
# Total 492 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-04-01T00:00:00Z and 2009-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 210 records retrieved.
# Retrieval complete for logs between 2009-05-01T00:00:00Z and 2009-06-01T00:00:00Z.
# Total 210 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-05-01T00:00:00Z and 2009-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 300 records retrieved.
# Retrieval complete for logs between 2009-06-01T00:00:00Z and 2009-07-01T00:00:00Z.
# Total 300 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-06-01T00:00:00Z and 2009-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 273 records retrieved.
# Retrieval complete for logs between 2009-07-01T00:00:00Z and 2009-08-01T00:00:00Z.
# Total 273 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-07-01T00:00:00Z and 2009-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 500 records retrieved.
# Search with continue index: 20090830202555|24386570, 39 records retrieved.
# Retrieval complete for logs between 2009-08-01T00:00:00Z and 2009-09-01T00:00:00Z.
# Total 539 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-08-01T00:00:00Z and 2009-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 326 records retrieved.
# Retrieval complete for logs between 2009-09-01T00:00:00Z and 2009-10-01T00:00:00Z.
# Total 326 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-09-01T00:00:00Z and 2009-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 172 records retrieved.
# Retrieval complete for logs between 2009-10-01T00:00:00Z and 2009-11-01T00:00:00Z.
# Total 172 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-10-01T00:00:00Z and 2009-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 229 records retrieved.
# Retrieval complete for logs between 2009-11-01T00:00:00Z and 2009-12-01T00:00:00Z.
# Total 229 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-11-01T00:00:00Z and 2009-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 239 records retrieved.
# Retrieval complete for logs between 2009-12-01T00:00:00Z and 2010-01-01T00:00:00Z.
# Total 239 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2009-12-01T00:00:00Z and 2010-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 265 records retrieved.
# Retrieval complete for logs between 2010-01-01T00:00:00Z and 2010-02-01T00:00:00Z.
# Total 265 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-01-01T00:00:00Z and 2010-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 304 records retrieved.
# Retrieval complete for logs between 2010-02-01T00:00:00Z and 2010-03-01T00:00:00Z.
# Total 304 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-02-01T00:00:00Z and 2010-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 338 records retrieved.
# Retrieval complete for logs between 2010-03-01T00:00:00Z and 2010-04-01T00:00:00Z.
# Total 338 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-03-01T00:00:00Z and 2010-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 439 records retrieved.
# Retrieval complete for logs between 2010-04-01T00:00:00Z and 2010-05-01T00:00:00Z.
# Total 439 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-04-01T00:00:00Z and 2010-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 228 records retrieved.
# Retrieval complete for logs between 2010-05-01T00:00:00Z and 2010-06-01T00:00:00Z.
# Total 228 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-05-01T00:00:00Z and 2010-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 131 records retrieved.
# Retrieval complete for logs between 2010-06-01T00:00:00Z and 2010-07-01T00:00:00Z.
# Total 131 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-06-01T00:00:00Z and 2010-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 181 records retrieved.
# Retrieval complete for logs between 2010-07-01T00:00:00Z and 2010-08-01T00:00:00Z.
# Total 181 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-07-01T00:00:00Z and 2010-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 197 records retrieved.
# Retrieval complete for logs between 2010-08-01T00:00:00Z and 2010-09-01T00:00:00Z.
# Total 197 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-08-01T00:00:00Z and 2010-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 220 records retrieved.
# Retrieval complete for logs between 2010-09-01T00:00:00Z and 2010-10-01T00:00:00Z.
# Total 220 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-09-01T00:00:00Z and 2010-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 162 records retrieved.
# Retrieval complete for logs between 2010-10-01T00:00:00Z and 2010-11-01T00:00:00Z.
# Total 162 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-10-01T00:00:00Z and 2010-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 131 records retrieved.
# Retrieval complete for logs between 2010-11-01T00:00:00Z and 2010-12-01T00:00:00Z.
# Total 131 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-11-01T00:00:00Z and 2010-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 157 records retrieved.
# Retrieval complete for logs between 2010-12-01T00:00:00Z and 2011-01-01T00:00:00Z.
# Total 157 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2010-12-01T00:00:00Z and 2011-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 182 records retrieved.
# Retrieval complete for logs between 2011-01-01T00:00:00Z and 2011-02-01T00:00:00Z.
# Total 182 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-01-01T00:00:00Z and 2011-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 133 records retrieved.
# Retrieval complete for logs between 2011-02-01T00:00:00Z and 2011-03-01T00:00:00Z.
# Total 133 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-02-01T00:00:00Z and 2011-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 156 records retrieved.
# Retrieval complete for logs between 2011-03-01T00:00:00Z and 2011-04-01T00:00:00Z.
# Total 156 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-03-01T00:00:00Z and 2011-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 259 records retrieved.
# Retrieval complete for logs between 2011-04-01T00:00:00Z and 2011-05-01T00:00:00Z.
# Total 259 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-04-01T00:00:00Z and 2011-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 206 records retrieved.
# Retrieval complete for logs between 2011-05-01T00:00:00Z and 2011-06-01T00:00:00Z.
# Total 206 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-05-01T00:00:00Z and 2011-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 100 records retrieved.
# Retrieval complete for logs between 2011-06-01T00:00:00Z and 2011-07-01T00:00:00Z.
# Total 100 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-06-01T00:00:00Z and 2011-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 83 records retrieved.
# Retrieval complete for logs between 2011-07-01T00:00:00Z and 2011-08-01T00:00:00Z.
# Total 83 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-07-01T00:00:00Z and 2011-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 150 records retrieved.
# Retrieval complete for logs between 2011-08-01T00:00:00Z and 2011-09-01T00:00:00Z.
# Total 150 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-08-01T00:00:00Z and 2011-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 152 records retrieved.
# Retrieval complete for logs between 2011-09-01T00:00:00Z and 2011-10-01T00:00:00Z.
# Total 152 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-09-01T00:00:00Z and 2011-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 148 records retrieved.
# Retrieval complete for logs between 2011-10-01T00:00:00Z and 2011-11-01T00:00:00Z.
# Total 148 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-10-01T00:00:00Z and 2011-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 164 records retrieved.
# Retrieval complete for logs between 2011-11-01T00:00:00Z and 2011-12-01T00:00:00Z.
# Total 164 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-11-01T00:00:00Z and 2011-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 190 records retrieved.
# Retrieval complete for logs between 2011-12-01T00:00:00Z and 2012-01-01T00:00:00Z.
# Total 190 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2011-12-01T00:00:00Z and 2012-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 145 records retrieved.
# Retrieval complete for logs between 2012-01-01T00:00:00Z and 2012-02-01T00:00:00Z.
# Total 145 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-01-01T00:00:00Z and 2012-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 241 records retrieved.
# Retrieval complete for logs between 2012-02-01T00:00:00Z and 2012-03-01T00:00:00Z.
# Total 241 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-02-01T00:00:00Z and 2012-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 102 records retrieved.
# Retrieval complete for logs between 2012-03-01T00:00:00Z and 2012-04-01T00:00:00Z.
# Total 102 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-03-01T00:00:00Z and 2012-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 139 records retrieved.
# Retrieval complete for logs between 2012-04-01T00:00:00Z and 2012-05-01T00:00:00Z.
# Total 139 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-04-01T00:00:00Z and 2012-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 88 records retrieved.
# Retrieval complete for logs between 2012-05-01T00:00:00Z and 2012-06-01T00:00:00Z.
# Total 88 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-05-01T00:00:00Z and 2012-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 108 records retrieved.
# Retrieval complete for logs between 2012-06-01T00:00:00Z and 2012-07-01T00:00:00Z.
# Total 108 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-06-01T00:00:00Z and 2012-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 91 records retrieved.
# Retrieval complete for logs between 2012-07-01T00:00:00Z and 2012-08-01T00:00:00Z.
# Total 91 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-07-01T00:00:00Z and 2012-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 163 records retrieved.
# Retrieval complete for logs between 2012-08-01T00:00:00Z and 2012-09-01T00:00:00Z.
# Total 163 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-08-01T00:00:00Z and 2012-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 206 records retrieved.
# Retrieval complete for logs between 2012-09-01T00:00:00Z and 2012-10-01T00:00:00Z.
# Total 206 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-09-01T00:00:00Z and 2012-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 122 records retrieved.
# Retrieval complete for logs between 2012-10-01T00:00:00Z and 2012-11-01T00:00:00Z.
# Total 122 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-10-01T00:00:00Z and 2012-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 73 records retrieved.
# Retrieval complete for logs between 2012-11-01T00:00:00Z and 2012-12-01T00:00:00Z.
# Total 73 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-11-01T00:00:00Z and 2012-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 182 records retrieved.
# Retrieval complete for logs between 2012-12-01T00:00:00Z and 2013-01-01T00:00:00Z.
# Total 182 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2012-12-01T00:00:00Z and 2013-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 183 records retrieved.
# Retrieval complete for logs between 2013-01-01T00:00:00Z and 2013-02-01T00:00:00Z.
# Total 183 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-01-01T00:00:00Z and 2013-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 149 records retrieved.
# Retrieval complete for logs between 2013-02-01T00:00:00Z and 2013-03-01T00:00:00Z.
# Total 149 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-02-01T00:00:00Z and 2013-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 145 records retrieved.
# Retrieval complete for logs between 2013-03-01T00:00:00Z and 2013-04-01T00:00:00Z.
# Total 145 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-03-01T00:00:00Z and 2013-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 238 records retrieved.
# Retrieval complete for logs between 2013-04-01T00:00:00Z and 2013-05-01T00:00:00Z.
# Total 238 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-04-01T00:00:00Z and 2013-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 150 records retrieved.
# Retrieval complete for logs between 2013-05-01T00:00:00Z and 2013-06-01T00:00:00Z.
# Total 150 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-05-01T00:00:00Z and 2013-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 192 records retrieved.
# Retrieval complete for logs between 2013-06-01T00:00:00Z and 2013-07-01T00:00:00Z.
# Total 192 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-06-01T00:00:00Z and 2013-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 143 records retrieved.
# Retrieval complete for logs between 2013-07-01T00:00:00Z and 2013-08-01T00:00:00Z.
# Total 143 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-07-01T00:00:00Z and 2013-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 64 records retrieved.
# Retrieval complete for logs between 2013-08-01T00:00:00Z and 2013-09-01T00:00:00Z.
# Total 64 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-08-01T00:00:00Z and 2013-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 151 records retrieved.
# Retrieval complete for logs between 2013-09-01T00:00:00Z and 2013-10-01T00:00:00Z.
# Total 151 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-09-01T00:00:00Z and 2013-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 68 records retrieved.
# Retrieval complete for logs between 2013-10-01T00:00:00Z and 2013-11-01T00:00:00Z.
# Total 68 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-10-01T00:00:00Z and 2013-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 47 records retrieved.
# Retrieval complete for logs between 2013-11-01T00:00:00Z and 2013-12-01T00:00:00Z.
# Total 47 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-11-01T00:00:00Z and 2013-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 45 records retrieved.
# Retrieval complete for logs between 2013-12-01T00:00:00Z and 2014-01-01T00:00:00Z.
# Total 45 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2013-12-01T00:00:00Z and 2014-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 138 records retrieved.
# Retrieval complete for logs between 2014-01-01T00:00:00Z and 2014-02-01T00:00:00Z.
# Total 138 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-01-01T00:00:00Z and 2014-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 48 records retrieved.
# Retrieval complete for logs between 2014-02-01T00:00:00Z and 2014-03-01T00:00:00Z.
# Total 48 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-02-01T00:00:00Z and 2014-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 138 records retrieved.
# Retrieval complete for logs between 2014-03-01T00:00:00Z and 2014-04-01T00:00:00Z.
# Total 138 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-03-01T00:00:00Z and 2014-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 110 records retrieved.
# Retrieval complete for logs between 2014-04-01T00:00:00Z and 2014-05-01T00:00:00Z.
# Total 110 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-04-01T00:00:00Z and 2014-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 80 records retrieved.
# Retrieval complete for logs between 2014-05-01T00:00:00Z and 2014-06-01T00:00:00Z.
# Total 80 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-05-01T00:00:00Z and 2014-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 56 records retrieved.
# Retrieval complete for logs between 2014-06-01T00:00:00Z and 2014-07-01T00:00:00Z.
# Total 56 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-06-01T00:00:00Z and 2014-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 114 records retrieved.
# Retrieval complete for logs between 2014-07-01T00:00:00Z and 2014-08-01T00:00:00Z.
# Total 114 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-07-01T00:00:00Z and 2014-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 109 records retrieved.
# Retrieval complete for logs between 2014-08-01T00:00:00Z and 2014-09-01T00:00:00Z.
# Total 109 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-08-01T00:00:00Z and 2014-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 98 records retrieved.
# Retrieval complete for logs between 2014-09-01T00:00:00Z and 2014-10-01T00:00:00Z.
# Total 98 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-09-01T00:00:00Z and 2014-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 73 records retrieved.
# Retrieval complete for logs between 2014-10-01T00:00:00Z and 2014-11-01T00:00:00Z.
# Total 73 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-10-01T00:00:00Z and 2014-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 72 records retrieved.
# Retrieval complete for logs between 2014-11-01T00:00:00Z and 2014-12-01T00:00:00Z.
# Total 72 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-11-01T00:00:00Z and 2014-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 146 records retrieved.
# Retrieval complete for logs between 2014-12-01T00:00:00Z and 2015-01-01T00:00:00Z.
# Total 146 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2014-12-01T00:00:00Z and 2015-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 111 records retrieved.
# Retrieval complete for logs between 2015-01-01T00:00:00Z and 2015-02-01T00:00:00Z.
# Total 111 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-01-01T00:00:00Z and 2015-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 219 records retrieved.
# Retrieval complete for logs between 2015-02-01T00:00:00Z and 2015-03-01T00:00:00Z.
# Total 219 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-02-01T00:00:00Z and 2015-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 107 records retrieved.
# Retrieval complete for logs between 2015-03-01T00:00:00Z and 2015-04-01T00:00:00Z.
# Total 107 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-03-01T00:00:00Z and 2015-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 127 records retrieved.
# Retrieval complete for logs between 2015-04-01T00:00:00Z and 2015-05-01T00:00:00Z.
# Total 127 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-04-01T00:00:00Z and 2015-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 105 records retrieved.
# Retrieval complete for logs between 2015-05-01T00:00:00Z and 2015-06-01T00:00:00Z.
# Total 105 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-05-01T00:00:00Z and 2015-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 101 records retrieved.
# Retrieval complete for logs between 2015-06-01T00:00:00Z and 2015-07-01T00:00:00Z.
# Total 101 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-06-01T00:00:00Z and 2015-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 204 records retrieved.
# Retrieval complete for logs between 2015-07-01T00:00:00Z and 2015-08-01T00:00:00Z.
# Total 204 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-07-01T00:00:00Z and 2015-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 216 records retrieved.
# Retrieval complete for logs between 2015-08-01T00:00:00Z and 2015-09-01T00:00:00Z.
# Total 216 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-08-01T00:00:00Z and 2015-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 128 records retrieved.
# Retrieval complete for logs between 2015-09-01T00:00:00Z and 2015-10-01T00:00:00Z.
# Total 128 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-09-01T00:00:00Z and 2015-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 99 records retrieved.
# Retrieval complete for logs between 2015-10-01T00:00:00Z and 2015-11-01T00:00:00Z.
# Total 99 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-10-01T00:00:00Z and 2015-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 100 records retrieved.
# Retrieval complete for logs between 2015-11-01T00:00:00Z and 2015-12-01T00:00:00Z.
# Total 100 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-11-01T00:00:00Z and 2015-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 112 records retrieved.
# Retrieval complete for logs between 2015-12-01T00:00:00Z and 2016-01-01T00:00:00Z.
# Total 112 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2015-12-01T00:00:00Z and 2016-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 127 records retrieved.
# Retrieval complete for logs between 2016-01-01T00:00:00Z and 2016-02-01T00:00:00Z.
# Total 127 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-01-01T00:00:00Z and 2016-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 42 records retrieved.
# Retrieval complete for logs between 2016-02-01T00:00:00Z and 2016-03-01T00:00:00Z.
# Total 42 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-02-01T00:00:00Z and 2016-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 45 records retrieved.
# Retrieval complete for logs between 2016-03-01T00:00:00Z and 2016-04-01T00:00:00Z.
# Total 45 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-03-01T00:00:00Z and 2016-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 134 records retrieved.
# Retrieval complete for logs between 2016-04-01T00:00:00Z and 2016-05-01T00:00:00Z.
# Total 134 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-04-01T00:00:00Z and 2016-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 94 records retrieved.
# Retrieval complete for logs between 2016-05-01T00:00:00Z and 2016-06-01T00:00:00Z.
# Total 94 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-05-01T00:00:00Z and 2016-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 212 records retrieved.
# Retrieval complete for logs between 2016-06-01T00:00:00Z and 2016-07-01T00:00:00Z.
# Total 212 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-06-01T00:00:00Z and 2016-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 180 records retrieved.
# Retrieval complete for logs between 2016-07-01T00:00:00Z and 2016-08-01T00:00:00Z.
# Total 180 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-07-01T00:00:00Z and 2016-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 140 records retrieved.
# Retrieval complete for logs between 2016-08-01T00:00:00Z and 2016-09-01T00:00:00Z.
# Total 140 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-08-01T00:00:00Z and 2016-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 168 records retrieved.
# Retrieval complete for logs between 2016-09-01T00:00:00Z and 2016-10-01T00:00:00Z.
# Total 168 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-09-01T00:00:00Z and 2016-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 83 records retrieved.
# Retrieval complete for logs between 2016-10-01T00:00:00Z and 2016-11-01T00:00:00Z.
# Total 83 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-10-01T00:00:00Z and 2016-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 201 records retrieved.
# Retrieval complete for logs between 2016-11-01T00:00:00Z and 2016-12-01T00:00:00Z.
# Total 201 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-11-01T00:00:00Z and 2016-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 307 records retrieved.
# Retrieval complete for logs between 2016-12-01T00:00:00Z and 2017-01-01T00:00:00Z.
# Total 307 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2016-12-01T00:00:00Z and 2017-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 315 records retrieved.
# Retrieval complete for logs between 2017-01-01T00:00:00Z and 2017-02-01T00:00:00Z.
# Total 315 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-01-01T00:00:00Z and 2017-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 134 records retrieved.
# Retrieval complete for logs between 2017-02-01T00:00:00Z and 2017-03-01T00:00:00Z.
# Total 134 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-02-01T00:00:00Z and 2017-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 104 records retrieved.
# Retrieval complete for logs between 2017-03-01T00:00:00Z and 2017-04-01T00:00:00Z.
# Total 104 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-03-01T00:00:00Z and 2017-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 151 records retrieved.
# Retrieval complete for logs between 2017-04-01T00:00:00Z and 2017-05-01T00:00:00Z.
# Total 151 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-04-01T00:00:00Z and 2017-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 138 records retrieved.
# Retrieval complete for logs between 2017-05-01T00:00:00Z and 2017-06-01T00:00:00Z.
# Total 138 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-05-01T00:00:00Z and 2017-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 72 records retrieved.
# Retrieval complete for logs between 2017-06-01T00:00:00Z and 2017-07-01T00:00:00Z.
# Total 72 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-06-01T00:00:00Z and 2017-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 92 records retrieved.
# Retrieval complete for logs between 2017-07-01T00:00:00Z and 2017-08-01T00:00:00Z.
# Total 92 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-07-01T00:00:00Z and 2017-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 194 records retrieved.
# Retrieval complete for logs between 2017-08-01T00:00:00Z and 2017-09-01T00:00:00Z.
# Total 194 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-08-01T00:00:00Z and 2017-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 148 records retrieved.
# Retrieval complete for logs between 2017-09-01T00:00:00Z and 2017-10-01T00:00:00Z.
# Total 148 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-09-01T00:00:00Z and 2017-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 128 records retrieved.
# Retrieval complete for logs between 2017-10-01T00:00:00Z and 2017-11-01T00:00:00Z.
# Total 128 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-10-01T00:00:00Z and 2017-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 188 records retrieved.
# Retrieval complete for logs between 2017-11-01T00:00:00Z and 2017-12-01T00:00:00Z.
# Total 188 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-11-01T00:00:00Z and 2017-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 126 records retrieved.
# Retrieval complete for logs between 2017-12-01T00:00:00Z and 2018-01-01T00:00:00Z.
# Total 126 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2017-12-01T00:00:00Z and 2018-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 119 records retrieved.
# Retrieval complete for logs between 2018-01-01T00:00:00Z and 2018-02-01T00:00:00Z.
# Total 119 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2018-01-01T00:00:00Z and 2018-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 60 records retrieved.
# Retrieval complete for logs between 2018-02-01T00:00:00Z and 2018-03-01T00:00:00Z.
# Total 60 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2018-02-01T00:00:00Z and 2018-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 73 records retrieved.
# Retrieval complete for logs between 2018-03-01T00:00:00Z and 2018-04-01T00:00:00Z.
# Total 73 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2018-03-01T00:00:00Z and 2018-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 190 records retrieved.
# Retrieval complete for logs between 2018-04-01T00:00:00Z and 2018-05-01T00:00:00Z.
# Total 190 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2018-04-01T00:00:00Z and 2018-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 160 records retrieved.
# Retrieval complete for logs between 2018-05-01T00:00:00Z and 2018-06-01T00:00:00Z.
# Total 160 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2018-05-01T00:00:00Z and 2018-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 216 records retrieved.
# Retrieval complete for logs between 2018-06-01T00:00:00Z and 2018-07-01T00:00:00Z.
# Total 216 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2018-06-01T00:00:00Z and 2018-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 186 records retrieved.
# Retrieval complete for logs between 2018-07-01T00:00:00Z and 2018-08-01T00:00:00Z.
# Total 186 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2018-07-01T00:00:00Z and 2018-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 115 records retrieved.
# Retrieval complete for logs between 2018-08-01T00:00:00Z and 2018-09-01T00:00:00Z.
# Total 115 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2018-08-01T00:00:00Z and 2018-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 158 records retrieved.
# Retrieval complete for logs between 2018-09-01T00:00:00Z and 2018-10-01T00:00:00Z.
# ...
# Retrieval complete for logs between 2020-06-01T00:00:00Z and 2020-07-01T00:00:00Z.
# Total 142 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2020-06-01T00:00:00Z and 2020-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 76 records retrieved.
# Retrieval complete for logs between 2020-07-01T00:00:00Z and 2020-08-01T00:00:00Z.
# Total 76 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2020-07-01T00:00:00Z and 2020-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 62 records retrieved.
# Retrieval complete for logs between 2020-08-01T00:00:00Z and 2020-09-01T00:00:00Z.
# Total 62 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2020-08-01T00:00:00Z and 2020-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 76 records retrieved.
# Retrieval complete for logs between 2020-09-01T00:00:00Z and 2020-10-01T00:00:00Z.
# Total 76 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2020-09-01T00:00:00Z and 2020-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 124 records retrieved.
# Retrieval complete for logs between 2020-10-01T00:00:00Z and 2020-11-01T00:00:00Z.
# Total 124 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2020-10-01T00:00:00Z and 2020-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 108 records retrieved.
# Retrieval complete for logs between 2020-11-01T00:00:00Z and 2020-12-01T00:00:00Z.
# Total 108 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2020-11-01T00:00:00Z and 2020-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 60 records retrieved.
# Retrieval complete for logs between 2020-12-01T00:00:00Z and 2021-01-01T00:00:00Z.
# Total 60 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2020-12-01T00:00:00Z and 2021-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 131 records retrieved.
# Retrieval complete for logs between 2021-01-01T00:00:00Z and 2021-02-01T00:00:00Z.
# Total 131 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-01-01T00:00:00Z and 2021-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 132 records retrieved.
# Retrieval complete for logs between 2021-02-01T00:00:00Z and 2021-03-01T00:00:00Z.
# Total 132 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-02-01T00:00:00Z and 2021-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 120 records retrieved.
# Retrieval complete for logs between 2021-03-01T00:00:00Z and 2021-04-01T00:00:00Z.
# Total 120 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-03-01T00:00:00Z and 2021-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 105 records retrieved.
# Retrieval complete for logs between 2021-04-01T00:00:00Z and 2021-05-01T00:00:00Z.
# Total 105 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-04-01T00:00:00Z and 2021-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 139 records retrieved.
# Retrieval complete for logs between 2021-05-01T00:00:00Z and 2021-06-01T00:00:00Z.
# Total 139 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-05-01T00:00:00Z and 2021-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 56 records retrieved.
# Retrieval complete for logs between 2021-06-01T00:00:00Z and 2021-07-01T00:00:00Z.
# Total 56 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-06-01T00:00:00Z and 2021-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 127 records retrieved.
# Retrieval complete for logs between 2021-07-01T00:00:00Z and 2021-08-01T00:00:00Z.
# Total 127 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-07-01T00:00:00Z and 2021-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 154 records retrieved.
# Retrieval complete for logs between 2021-08-01T00:00:00Z and 2021-09-01T00:00:00Z.
# Total 154 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-08-01T00:00:00Z and 2021-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 131 records retrieved.
# Retrieval complete for logs between 2021-09-01T00:00:00Z and 2021-10-01T00:00:00Z.
# Total 131 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-09-01T00:00:00Z and 2021-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 198 records retrieved.
# Retrieval complete for logs between 2021-10-01T00:00:00Z and 2021-11-01T00:00:00Z.
# Total 198 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-10-01T00:00:00Z and 2021-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 164 records retrieved.
# Retrieval complete for logs between 2021-11-01T00:00:00Z and 2021-12-01T00:00:00Z.
# Total 164 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-11-01T00:00:00Z and 2021-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 151 records retrieved.
# Retrieval complete for logs between 2021-12-01T00:00:00Z and 2022-01-01T00:00:00Z.
# Total 151 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2021-12-01T00:00:00Z and 2022-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 170 records retrieved.
# Retrieval complete for logs between 2022-01-01T00:00:00Z and 2022-02-01T00:00:00Z.
# Total 170 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-01-01T00:00:00Z and 2022-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 240 records retrieved.
# Retrieval complete for logs between 2022-02-01T00:00:00Z and 2022-03-01T00:00:00Z.
# Total 240 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-02-01T00:00:00Z and 2022-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 219 records retrieved.
# Retrieval complete for logs between 2022-03-01T00:00:00Z and 2022-04-01T00:00:00Z.
# Total 219 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-03-01T00:00:00Z and 2022-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 260 records retrieved.
# Retrieval complete for logs between 2022-04-01T00:00:00Z and 2022-05-01T00:00:00Z.
# Total 260 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-04-01T00:00:00Z and 2022-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 238 records retrieved.
# Retrieval complete for logs between 2022-05-01T00:00:00Z and 2022-06-01T00:00:00Z.
# Total 238 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-05-01T00:00:00Z and 2022-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 128 records retrieved.
# Retrieval complete for logs between 2022-06-01T00:00:00Z and 2022-07-01T00:00:00Z.
# Total 128 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-06-01T00:00:00Z and 2022-07-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 154 records retrieved.
# Retrieval complete for logs between 2022-07-01T00:00:00Z and 2022-08-01T00:00:00Z.
# Total 154 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-07-01T00:00:00Z and 2022-08-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 162 records retrieved.
# Retrieval complete for logs between 2022-08-01T00:00:00Z and 2022-09-01T00:00:00Z.
# Total 162 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-08-01T00:00:00Z and 2022-09-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 100 records retrieved.
# Retrieval complete for logs between 2022-09-01T00:00:00Z and 2022-10-01T00:00:00Z.
# Total 100 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-09-01T00:00:00Z and 2022-10-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 379 records retrieved.
# Retrieval complete for logs between 2022-10-01T00:00:00Z and 2022-11-01T00:00:00Z.
# Total 379 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-10-01T00:00:00Z and 2022-11-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 147 records retrieved.
# Retrieval complete for logs between 2022-11-01T00:00:00Z and 2022-12-01T00:00:00Z.
# Total 147 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-11-01T00:00:00Z and 2022-12-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 95 records retrieved.
# Retrieval complete for logs between 2022-12-01T00:00:00Z and 2023-01-01T00:00:00Z.
# Total 95 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2022-12-01T00:00:00Z and 2023-01-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 207 records retrieved.
# Retrieval complete for logs between 2023-01-01T00:00:00Z and 2023-02-01T00:00:00Z.
# Total 207 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2023-01-01T00:00:00Z and 2023-02-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 114 records retrieved.
# Retrieval complete for logs between 2023-02-01T00:00:00Z and 2023-03-01T00:00:00Z.
# Total 114 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2023-02-01T00:00:00Z and 2023-03-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 143 records retrieved.
# Retrieval complete for logs between 2023-03-01T00:00:00Z and 2023-04-01T00:00:00Z.
# Total 143 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2023-03-01T00:00:00Z and 2023-04-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 157 records retrieved.
# Retrieval complete for logs between 2023-04-01T00:00:00Z and 2023-05-01T00:00:00Z.
# Total 157 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2023-04-01T00:00:00Z and 2023-05-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 206 records retrieved.
# Retrieval complete for logs between 2023-05-01T00:00:00Z and 2023-06-01T00:00:00Z.
# Total 206 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 0 records retrieved.
# Retrieval complete for logs between 2023-05-01T00:00:00Z and 2023-06-01T00:00:00Z.
# No record was retrieved or saved.
# Retrieving logevent type: abusefilter
# 134 records retrieved.
# Retrieval complete for logs between 2023-06-01T00:00:00Z and 2023-07-01T00:00:00Z.
# Total 134 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 3 records retrieved.
# Retrieval complete for logs between 2023-06-01T00:00:00Z and 2023-07-01T00:00:00Z.
# Total 3 records retrieved & saved.
# Retrieving logevent type: abusefilter
# 106 records retrieved.
# Retrieval complete for logs between 2023-07-01T00:00:00Z and 2023-08-01T00:00:00Z.
# Total 106 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 2 records retrieved.
# Retrieval complete for logs between 2023-07-01T00:00:00Z and 2023-08-01T00:00:00Z.
# Total 2 records retrieved & saved.
# Retrieving logevent type: abusefilter
# 178 records retrieved.
# Retrieval complete for logs between 2023-08-01T00:00:00Z and 2023-09-01T00:00:00Z.
# Total 178 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 25 records retrieved.
# Retrieval complete for logs between 2023-08-01T00:00:00Z and 2023-09-01T00:00:00Z.
# Total 25 records retrieved & saved.
# Retrieving logevent type: abusefilter
# 116 records retrieved.
# Retrieval complete for logs between 2023-09-01T00:00:00Z and 2023-10-01T00:00:00Z.
# Total 116 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 53 records retrieved.
# Retrieval complete for logs between 2023-09-01T00:00:00Z and 2023-10-01T00:00:00Z.
# Total 53 records retrieved & saved.
# Retrieving logevent type: abusefilter
# 219 records retrieved.
# Retrieval complete for logs between 2023-10-01T00:00:00Z and 2023-11-01T00:00:00Z.
# Total 219 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 32 records retrieved.
# Retrieval complete for logs between 2023-10-01T00:00:00Z and 2023-11-01T00:00:00Z.
# Total 32 records retrieved & saved.
# Retrieving logevent type: abusefilter
# 214 records retrieved.
# Retrieval complete for logs between 2023-11-01T00:00:00Z and 2023-12-01T00:00:00Z.
# Total 214 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 88 records retrieved.
# Retrieval complete for logs between 2023-11-01T00:00:00Z and 2023-12-01T00:00:00Z.
# Total 88 records retrieved & saved.
# Retrieving logevent type: abusefilter
# 363 records retrieved.
# Retrieval complete for logs between 2023-12-01T00:00:00Z and 2024-01-01T00:00:00Z.
# Total 363 records retrieved & saved.
# Retrieving logevent type: abusefilterblockeddomainhit
# 47 records retrieved.
# Retrieval complete for logs between 2023-12-01T00:00:00Z and 2024-01-01T00:00:00Z.
# Total 47 records retrieved & saved.
