# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook explains how to run the program to fetch abuselogs from Wikipedia API.

# %%
import requests
import pandas as pd

# %%
# append system path to import spider program
import sys
sys.path.append('../')
from utils.spider_abuselog import retrieve_abuselog_month # fetch data for a specific month in a given year
from utils.spider_abuselog import retrieve_abuselog_year # fetch data for a given year

# %% [markdown]
# # Code examples

# %% [markdown]
# ## Retrieve data for 1 month

# %% [markdown]
# To retrieve abuselogs for a specific month, please use the `retrieve_abuselog_month` function. It automatically retrieves the logs and write them into a local csv file (format: year-month.csv).
#
# It requires 5 parameters:
# - request_session:
#     - A request session to sent API requests.
# - year (int):
#     - The year for which block logs should be retrieved.
# - month (int):
#     - The month for which block logs should be retrieved.
# - folder_path (str):
#     - The folder path where the CSV file will be saved.
#     - Example: './data/abusefilter_logs/'
# - compress (bool):
#     - Specify if compress the CSV file into a gz file.
#     - Default to False

# %% [markdown]
# **Note:**
# - The first abuselog was in March 2009.
# - If 0 record is retrieved, no csv will be created.
# - If you encounter issues at running the function, please check if a file already exists on your local disk. This function automatically stop to prevent from overwritting local file.

# %%
# Set folder path to store fetched data
folder_path = '../data/abuselogs/'

# %%
for month in range(6, 13, 1):
    s = requests.Session()
    retrieve_abuselog_month(request_session=s, year=2010, month=month, folder_path=folder_path, compress=True)
# Out:
# 0 records retrieved.
# Retrieval complete for logs between 2009-01-01T00:00:00Z and 2009-02-01T00:00:00Z.
# No record was retrieved or saved.
# 0 records retrieved.
# Retrieval complete for logs between 2009-02-01T00:00:00Z and 2009-03-01T00:00:00Z.
# No record was retrieved or saved.

# %% [markdown]
# ## Retrieve data for 1 year

# %% [markdown]
# To retrieve block logs for a specific year, please use the retrieve_abuselog_year function. It automatically loops over the month retrive function to download and store logs for a given year. The data will be stored in 12 local csv files (format: year-month.csv), each for 1 month.
#
# It requires 3 parameters:
# - year (int):
#     - The year for which block logs should be retrieved.
# - folder_path (str):
#     - The folder path where the CSV file will be saved.
# - compress (bool):
#     - Specify if compress the CSV file into a gz file.
#     - Default to False

# %% [markdown]
# **Note:**
# - The first abuselog was in March 2009.
# - If 0 record is retrieved, no csv will be created.
# - If you encounter issues at running the function, please check if a file already exists on your local disk. This function automatically stop to prevent from overwritting local file.

# %%
# Set folder path to store fetched data
folder_path = '../data/abuselogs/'

# %%
for year in range(2010, 2016, 1):
    retrieve_abuselog_year(year=year, folder_path=folder_path, compress=True)
# Out:
# 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-01T03:02:04Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-01T06:03:47Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-01T09:11:53Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-01T14:51:48Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-01T18:49:07Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-01T21:31:59Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-01T23:57:56Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-02T02:31:23Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-02T05:44:40Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-02T09:41:38Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-02T14:37:14Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-02T17:31:38Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-02T19:53:01Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-02T21:48:55Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-03T00:09:24Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-03T02:21:12Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-03T04:04:25Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-03T06:19:55Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-03T10:24:38Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-03T15:08:00Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-03T17:55:42Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-03T20:16:43Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-03T21:56:27Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-04T00:29:29Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-04T02:53:18Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-04T05:51:40Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-04T09:44:40Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-04T13:23:23Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-04T15:52:56Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-04T17:38:03Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-04T19:06:42Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-04T20:34:49Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-04T22:02:41Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-04T23:24:29Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T01:11:42Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T03:01:10Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T05:41:17Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T09:50:25Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T13:17:24Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T15:10:14Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T16:47:47Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T17:49:42Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T19:10:44Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T20:25:30Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T21:47:19Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-05T23:18:33Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-06T00:36:43Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-06T02:36:16Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-06T04:55:34Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-06T09:04:00Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-06T12:40:53Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-06T14:42:01Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-06T16:01:13Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-06T17:18:08Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-01-06
z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-27T07:30:21Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-27T10:24:40Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-27T13:09:00Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-27T14:50:14Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-27T16:27:50Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-27T18:06:02Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-27T19:29:47Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-27T21:00:41Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-27T22:43:36Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-28T00:23:45Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-28T02:24:02Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-28T04:41:42Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-28T08:15:17Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-28T10:47:18Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-28T13:19:22Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-28T15:01:44Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-28T16:47:00Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-28T18:10:32Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-28T19:47:51Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-28T21:48:34Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-29T00:19:15Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-29T03:08:23Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-29T05:11:08Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-29T08:55:13Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-29T13:12:46Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-29T16:04:01Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-29T18:36:48Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-29T20:43:50Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-29T22:44:29Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-30T01:35:02Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-30T04:09:43Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-30T07:30:26Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-30T12:32:03Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-30T15:28:39Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-30T17:54:47Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-30T19:52:56Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-30T22:14:43Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-31T00:25:16Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-31T02:46:19Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-31T05:11:31Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-31T07:59:34Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-31T11:15:29Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-31T13:53:47Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-31T16:29:33Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-31T18:28:39Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-31T20:46:01Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-05-31T22:35:19Z', 'continue': '-||'}, 473 records retrieved.
# Retrieval complete for logs between 2010-05-01T00:00:00Z and 2010-06-01T00:00:00Z.
# Total 206973 records retrieved & saved.
# 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T01:33:34Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T03:49:57Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T06:51:55Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T09:39:29Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T12:24:29Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T13:57:18Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T15:12:17Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T16:33:44Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T18:17:03Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T19:39:41Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T20:52:04Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T22:03:26Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-01T23:53:20Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-02T01:20:35Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-02T03:03:15Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-02T05:50:31Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-02T08:52:24Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-02T11:46:15Z', 'continue': '-||'}, 500 records retrieved.
# Search with continue index: {'aflstart': '2010-06-02T14:03:56Z', 'continue': '-||'},
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 for year in range(2010, 2016, 1):
# ----> 2     retrieve_abuselog_year(year=year, folder_path=folder_path)
#
# File ~/Documents/France/Projects/wikipedia/wikipedia_scrapping/notebooks/../utils/spider_abuselog.py:184, in retrieve_abuselog_year(year, folder_path, compress)
#     182 for month in range(1, 13):
#     183     s = requests.Session()
# --> 184     retrieve_abuselog_month(
#     185         request_session=s,
#     186         year=year,
#     187         month=month,
#     188         folder_path=folder_path,
#     189         compress=compress)
#
# File ~/Documents/France/Projects/wikipedia/wikipedia_scrapping/notebooks/../utils/spider_abuselog.py:123, in retrieve_abuselog_month(request_session, year, month, folder_path, file_name, prevent_overwrite, compress)
#     120     print(f'Search with continue index: {continue_index}', end=', ')
#     122 # Send a request to retrieve block logs
# --> 123 logs, continue_index = retrieve_abuselog(
#     124     start_date=start_date,
#     125     end_date=end_date,
#     126     request_session=request_session,
#     127     continue_index=continue_index
#     128 )
#     130 # Convert logs into a dataframe
#     131 if len(logs) != 0:
#
# File ~/Documents/France/Projects/wikipedia/wikipedia_scrapping/notebooks/../utils/spider_abuselog.py:52, in retrieve_abuselog(request_session, start_date, end_date, continue_index)
#      49     parameters['aflstart'] = continue_index['aflstart']
#      51 # Send request
# ---> 52 r = request_session.get(url=url, params=parameters)
#      54 # parse data to json
#      55 data = r.json()
#
# File ~/Documents/France/Projects/wikipedia/wikipedia_scrapping/.venv/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/Documents/France/Projects/wikipedia/wikipedia_scrapping/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/France/Projects/wikipedia/wikipedia_scrapping/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/France/Projects/wikipedia/wikipedia_scrapping/.venv/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/Documents/France/Projects/wikipedia/wikipedia_scrapping/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/Documents/France/Projects/wikipedia/wikipedia_scrapping/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/France/Projects/wikipedia/wikipedia_scrapping/.venv/lib/python3.11/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
