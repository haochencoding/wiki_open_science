# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook explains how I extract robots from the administrator ('user') column from block log query csvs and from the Wikipedia APIs.

# %%
# append system path to import utils
import sys
sys.path.append('../')

# %% [markdown]
# # Extract all administrator names

# %% [markdown]
# The code below shows how to extract the names of all administrators. This information is extracted to identify bots among the administrators.

# %%
from utils.name_extraction import extract_administrator_names

# %%
dir_path = '../data/block_logs'

admin_names = extract_administrator_names(dir_path, start_year=2004, end_year=2023)
# Out:
# File not found: ../data/block_logs/2004/2004-01.csv
# File not found: ../data/block_logs/2004/2004-01.csv.gz
# File not found: ../data/block_logs/2004/2004-02.csv
# File not found: ../data/block_logs/2004/2004-02.csv.gz
# File not found: ../data/block_logs/2004/2004-03.csv
# File not found: ../data/block_logs/2004/2004-03.csv.gz
# File not found: ../data/block_logs/2004/2004-04.csv
# File not found: ../data/block_logs/2004/2004-04.csv.gz
# File not found: ../data/block_logs/2004/2004-05.csv
# File not found: ../data/block_logs/2004/2004-05.csv.gz
# File not found: ../data/block_logs/2004/2004-06.csv
# File not found: ../data/block_logs/2004/2004-06.csv.gz
# File not found: ../data/block_logs/2004/2004-07.csv
# File not found: ../data/block_logs/2004/2004-07.csv.gz
# File not found: ../data/block_logs/2004/2004-08.csv
# File not found: ../data/block_logs/2004/2004-08.csv.gz
# File not found: ../data/block_logs/2004/2004-09.csv
# File not found: ../data/block_logs/2004/2004-09.csv.gz
# File not found: ../data/block_logs/2004/2004-10.csv
# File not found: ../data/block_logs/2004/2004-10.csv.gz
# File not found: ../data/block_logs/2004/2004-11.csv
# File not found: ../data/block_logs/2004/2004-11.csv.gz
# Extracting: ../data/block_logs/2004/2004-12.csv.gz
# Extracting: ../data/block_logs/2005/2005-01.csv.gz
# Extracting: ../data/block_logs/2005/2005-02.csv.gz
# Extracting: ../data/block_logs/2005/2005-03.csv.gz
# Extracting: ../data/block_logs/2005/2005-04.csv.gz
# Extracting: ../data/block_logs/2005/2005-05.csv.gz
# Extracting: ../data/block_logs/2005/2005-06.csv.gz
# Extracting: ../data/block_logs/2005/2005-07.csv.gz
# Extracting: ../data/block_logs/2005/2005-08.csv.gz
# Extracting: ../data/block_logs/2005/2005-09.csv.gz
# Extracting: ../data/block_logs/2005/2005-10.csv.gz
# Extracting: ../data/block_logs/2005/2005-11.csv.gz
# Extracting: ../data/block_logs/2005/2005-12.csv.gz
# Extracting: ../data/block_logs/2006/2006-01.csv.gz
# Extracting: ../data/block_logs/2006/2006-02.csv.gz
# Extracting: ../data/block_logs/2006/2006-03.csv.gz
# Extracting: ../data/block_logs/2006/2006-04.csv.gz
# Extracting: ../data/block_logs/2006/2006-05.csv.gz
# Extracting: ../data/block_logs/2006/2006-06.csv.gz
# Extracting: ../data/block_logs/2006/2006-07.csv.gz
# Extracting: ../data/block_logs/2006/2006-08.csv.gz
# Extracting: ../data/block_logs/2006/2006-09.csv.gz
# Extracting: ../data/block_logs/2006/2006-10.csv.gz
# Extracting: ../data/block_logs/2006/2006-11.csv.gz
# Extracting: ../data/block_logs/2006/2006-12.csv.gz
# Extracting: ../data/block_logs/2007/2007-01.csv.gz
# Extracting: ../data/block_logs/2007/2007-02.csv.gz
# Extracting: ../data/block_logs/2007/2007-03.csv.gz
# Extracting: ../data/block_logs/2007/2007-04.csv.gz
# Extracting: ../data/block_logs/2007/2007-05.csv.gz
# Extracting: ../data/block_logs/2007/2007-06.csv.gz
# Extracting: ../data/block_logs/2007/2007-07.csv.gz
# Extracting: ../data/block_logs/2007/2007-08.csv.gz
# Extracting: ../data/block_logs/2007/2007-09.csv.gz
# Extracting: ../data/block_logs/2007/2007-10.csv.gz
# Extracting: ../data/block_logs/2007/2007-11.csv.gz
# Extracting: ../data/block_logs/2007/2007-12.csv.gz
# Extracting: ../data/block_logs/2008/2008-01.csv.gz
# Extracting: ../data/block_logs/2008/2008-02.csv.gz
# Extracting: ../data/block_logs/2008/2008-03.csv.gz
# Extracting: ../data/block_logs/2008/2008-04.csv.gz
# Extracting: ../data/block_logs/2008/2008-05.csv.gz
# Extracting: ../data/block_logs/2008/2008-06.csv.gz
# Extracting: ../data/block_logs/2008/2008-07.csv.gz
# Extracting: ../data/block_logs/2008/2008-08.csv.gz
# Extracting: ../data/block_logs/2008/2008-09.csv.gz
# Extracting: ../data/block_logs/2008/2008-10.csv.gz
# Extracting: ../data/block_logs/2008/2008-11.csv.gz
# Extracting: ../data/block_logs/2008/2008-12.csv.gz
# Extracting: ../data/block_logs/2009/2009-01.csv.gz
# Extracting: ../data/block_logs/2009/2009-02.csv.gz
# Extracting: ../data/block_logs/2009/2009-03.csv.gz
# Extracting: ../data/block_logs/2009/2009-04.csv.gz
# Extracting: ../data/block_logs/2009/2009-05.csv.gz
# Extracting: ../data/block_logs/2009/2009-06.csv.gz
# Extracting: ../data/block_logs/2009/2009-07.csv.gz
# Extracting: ../data/block_logs/2009/2009-08.csv.gz
# Extracting: ../data/block_logs/2009/2009-09.csv.gz
# Extracting: ../data/block_logs/2009/2009-10.csv.gz
# Extracting: ../data/block_logs/2009/2009-11.csv.gz
# Extracting: ../data/block_logs/2009/2009-12.csv.gz
# Extracting: ../data/block_logs/2010/2010-01.csv.gz
# Extracting: ../data/block_logs/2010/2010-02.csv.gz
# Extracting: ../data/block_logs/2010/2010-03.csv.gz
# Extracting: ../data/block_logs/2010/2010-04.csv.gz
# Extracting: ../data/block_logs/2010/2010-05.csv.gz
# Extracting: ../data/block_logs/2010/2010-06.csv.gz
# Extracting: ../data/block_logs/2010/2010-07.csv.gz
# Extracting: ../data/block_logs/2010/2010-08.csv.gz
# Extracting: ../data/block_logs/2010/2010-09.csv.gz
# Extracting: ../data/block_logs/2010/2010-10.csv.gz
# Extracting: ../data/block_logs/2010/2010-11.csv.gz
# Extracting: ../data/block_logs/2010/2010-12.csv.gz
# Extracting: ../data/block_logs/2011/2011-01.csv.gz
# Extracting: ../data/block_logs/2011/2011-02.csv.gz
# Extracting: ../data/block_logs/2011/2011-03.csv.gz
# Extracting: ../data/block_logs/2011/2011-04.csv.gz
# Extracting: ../data/block_logs/2011/2011-05.csv.gz
# Extracting: ../data/block_logs/2011/2011-06.csv.gz
# Extracting: ../data/block_logs/2011/2011-07.csv.gz
# Extracting: ../data/block_logs/2011/2011-08.csv.gz
# Extracting: ../data/block_logs/2011/2011-09.csv.gz
# Extracting: ../data/block_logs/2011/2011-10.csv.gz
# Extracting: ../data/block_logs/2011/2011-11.csv.gz
# Extracting: ../data/block_logs/2011/2011-12.csv.gz
# Extracting: ../data/block_logs/2012/2012-01.csv.gz
# Extracting: ../data/block_logs/2012/2012-02.csv.gz
# Extracting: ../data/block_logs/2012/2012-03.csv.gz
# Extracting: ../data/block_logs/2012/2012-04.csv.gz
# Extracting: ../data/block_logs/2012/2012-05.csv.gz
# Extracting: ../data/block_logs/2012/2012-06.csv.gz
# Extracting: ../data/block_logs/2012/2012-07.csv.gz
# Extracting: ../data/block_logs/2012/2012-08.csv.gz
# Extracting: ../data/block_logs/2012/2012-09.csv.gz
# Extracting: ../data/block_logs/2012/2012-10.csv.gz
# Extracting: ../data/block_logs/2012/2012-11.csv.gz
# Extracting: ../data/block_logs/2012/2012-12.csv.gz
# Extracting: ../data/block_logs/2013/2013-01.csv.gz
# Extracting: ../data/block_logs/2013/2013-02.csv.gz
# Extracting: ../data/block_logs/2013/2013-03.csv.gz
# Extracting: ../data/block_logs/2013/2013-04.csv.gz
# Extracting: ../data/block_logs/2013/2013-05.csv.gz
# Extracting: ../data/block_logs/2013/2013-06.csv.gz
# Extracting: ../data/block_logs/2013/2013-07.csv.gz
# Extracting: ../data/block_logs/2013/2013-08.csv.gz
# Extracting: ../data/block_logs/2013/2013-09.csv.gz
# Extracting: ../data/block_logs/2013/2013-10.csv.gz
# Extracting: ../data/block_logs/2013/2013-11.csv.gz
# Extracting: ../data/block_logs/2013/2013-12.csv.gz
# Extracting: ../data/block_logs/2014/2014-01.csv.gz
# Extracting: ../data/block_logs/2014/2014-02.csv.gz
# Extracting: ../data/block_logs/2014/2014-03.csv.gz
# Extracting: ../data/block_logs/2014/2014-04.csv.gz
# Extracting: ../data/block_logs/2014/2014-05.csv.gz
# Extracting: ../data/block_logs/2014/2014-06.csv.gz
# Extracting: ../data/block_logs/2014/2014-07.csv.gz
# Extracting: ../data/block_logs/2014/2014-08.csv.gz
# Extracting: ../data/block_logs/2014/2014-09.csv.gz
# Extracting: ../data/block_logs/2014/2014-10.csv.gz
# Extracting: ../data/block_logs/2014/2014-11.csv.gz
# Extracting: ../data/block_logs/2014/2014-12.csv.gz
# Extracting: ../data/block_logs/2015/2015-01.csv.gz
# Extracting: ../data/block_logs/2015/2015-02.csv.gz
# Extracting: ../data/block_logs/2015/2015-03.csv.gz
# Extracting: ../data/block_logs/2015/2015-04.csv.gz
# Extracting: ../data/block_logs/2015/2015-05.csv.gz
# Extracting: ../data/block_logs/2015/2015-06.csv.gz
# Extracting: ../data/block_logs/2015/2015-07.csv.gz
# Extracting: ../data/block_logs/2015/2015-08.csv.gz
# Extracting: ../data/block_logs/2015/2015-09.csv.gz
# Extracting: ../data/block_logs/2015/2015-10.csv.gz
# Extracting: ../data/block_logs/2015/2015-11.csv.gz
# Extracting: ../data/block_logs/2015/2015-12.csv.gz
# Extracting: ../data/block_logs/2016/2016-01.csv.gz
# Extracting: ../data/block_logs/2016/2016-02.csv.gz
# Extracting: ../data/block_logs/2016/2016-03.csv.gz
# Extracting: ../data/block_logs/2016/2016-04.csv.gz
# Extracting: ../data/block_logs/2016/2016-05.csv.gz
# Extracting: ../data/block_logs/2016/2016-06.csv.gz
# Extracting: ../data/block_logs/2016/2016-07.csv.gz
# Extracting: ../data/block_logs/2016/2016-08.csv.gz
# Extracting: ../data/block_logs/2016/2016-09.csv.gz
# Extracting: ../data/block_logs/2016/2016-10.csv.gz
# Extracting: ../data/block_logs/2016/2016-11.csv.gz
# Extracting: ../data/block_logs/2016/2016-12.csv.gz
# Extracting: ../data/block_logs/2017/2017-01.csv.gz
# Extracting: ../data/block_logs/2017/2017-02.csv.gz
# Extracting: ../data/block_logs/2017/2017-03.csv.gz
# Extracting: ../data/block_logs/2017/2017-04.csv.gz
# Extracting: ../data/block_logs/2017/2017-05.csv.gz
# Extracting: ../data/block_logs/2017/2017-06.csv.gz
# Extracting: ../data/block_logs/2017/2017-07.csv.gz
# Extracting: ../data/block_logs/2017/2017-08.csv.gz
# Extracting: ../data/block_logs/2017/2017-09.csv.gz
# Extracting: ../data/block_logs/2017/2017-10.csv.gz
# Extracting: ../data/block_logs/2017/2017-11.csv.gz
# Extracting: ../data/block_logs/2017/2017-12.csv.gz
# Extracting: ../data/block_logs/2018/2018-01.csv.gz
# Extracting: ../data/block_logs/2018/2018-02.csv.gz
# Extracting: ../data/block_logs/2018/2018-03.csv.gz
# Extracting: ../data/block_logs/2018/2018-04.csv.gz
# Extracting: ../data/block_logs/2018/2018-05.csv.gz
# Extracting: ../data/block_logs/2018/2018-06.csv.gz
# Extracting: ../data/block_logs/2018/2018-07.csv.gz
# Extracting: ../data/block_logs/2018/2018-08.csv.gz
# Extracting: ../data/block_logs/2018/2018-09.csv.gz
# Extracting: ../data/block_logs/2018/2018-10.csv.gz
# Extracting: ../data/block_logs/2018/2018-11.csv.gz
# Extracting: ../data/block_logs/2018/2018-12.csv.gz
# Extracting: ../data/block_logs/2019/2019-01.csv.gz
# Extracting: ../data/block_logs/2019/2019-02.csv.gz
# Extracting: ../data/block_logs/2019/2019-03.csv.gz
# Extracting: ../data/block_logs/2019/2019-04.csv.gz
# Extracting: ../data/block_logs/2019/2019-05.csv.gz
# Extracting: ../data/block_logs/2019/2019-06.csv.gz
# Extracting: ../data/block_logs/2019/2019-07.csv.gz
# Extracting: ../data/block_logs/2019/2019-08.csv.gz
# Extracting: ../data/block_logs/2019/2019-09.csv.gz
# Extracting: ../data/block_logs/2019/2019-10.csv.gz
# Extracting: ../data/block_logs/2019/2019-11.csv.gz
# Extracting: ../data/block_logs/2019/2019-12.csv.gz
# Extracting: ../data/block_logs/2020/2020-01.csv.gz
# Extracting: ../data/block_logs/2020/2020-02.csv.gz
# Extracting: ../data/block_logs/2020/2020-03.csv.gz
# Extracting: ../data/block_logs/2020/2020-04.csv.gz
# Extracting: ../data/block_logs/2020/2020-05.csv.gz
# Extracting: ../data/block_logs/2020/2020-06.csv.gz
# Extracting: ../data/block_logs/2020/2020-07.csv.gz
# Extracting: ../data/block_logs/2020/2020-08.csv.gz
# Extracting: ../data/block_logs/2020/2020-09.csv.gz
# Extracting: ../data/block_logs/2020/2020-10.csv.gz
# Extracting: ../data/block_logs/2020/2020-11.csv.gz
# Extracting: ../data/block_logs/2020/2020-12.csv.gz
# Extracting: ../data/block_logs/2021/2021-01.csv.gz
# Extracting: ../data/block_logs/2021/2021-02.csv.gz
# Extracting: ../data/block_logs/2021/2021-03.csv.gz
# Extracting: ../data/block_logs/2021/2021-04.csv.gz
# Extracting: ../data/block_logs/2021/2021-05.csv.gz
# Extracting: ../data/block_logs/2021/2021-06.csv.gz
# Extracting: ../data/block_logs/2021/2021-07.csv.gz
# Extracting: ../data/block_logs/2021/2021-08.csv.gz
# Extracting: ../data/block_logs/2021/2021-09.csv.gz
# Extracting: ../data/block_logs/2021/2021-10.csv.gz
# Extracting: ../data/block_logs/2021/2021-11.csv.gz
# Extracting: ../data/block_logs/2021/2021-12.csv.gz
# Extracting: ../data/block_logs/2022/2022-01.csv.gz
# Extracting: ../data/block_logs/2022/2022-02.csv.gz
# Extracting: ../data/block_logs/2022/2022-03.csv.gz
# Extracting: ../data/block_logs/2022/2022-04.csv.gz
# Extracting: ../data/block_logs/2022/2022-05.csv.gz
# Extracting: ../data/block_logs/2022/2022-06.csv.gz
# Extracting: ../data/block_logs/2022/2022-07.csv.gz
# Extracting: ../data/block_logs/2022/2022-08.csv.gz
# Extracting: ../data/block_logs/2022/2022-09.csv.gz
# Extracting: ../data/block_logs/2022/2022-10.csv.gz
# Extracting: ../data/block_logs/2022/2022-11.csv.gz
# Extracting: ../data/block_logs/2022/2022-12.csv.gz
# Extracting: ../data/block_logs/2023/2023-01.csv.gz
# Extracting: ../data/block_logs/2023/2023-02.csv.gz
# Extracting: ../data/block_logs/2023/2023-03.csv.gz
# Extracting: ../data/block_logs/2023/2023-04.csv.gz
# Extracting: ../data/block_logs/2023/2023-05.csv.gz
# Extracting: ../data/block_logs/2023/2023-06.csv.gz
# File not found: ../data/block_logs/2023/2023-07.csv
# File not found: ../data/block_logs/2023/2023-07.csv.gz
# File not found: ../data/block_logs/2023/2023-08.csv
# File not found: ../data/block_logs/2023/2023-08.csv.gz
# File not found: ../data/block_logs/2023/2023-09.csv
# File not found: ../data/block_logs/2023/2023-09.csv.gz
# File not found: ../data/block_logs/2023/2023-10.csv
# File not found: ../data/block_logs/2023/2023-10.csv.gz
# File not found: ../data/block_logs/2023/2023-11.csv
# File not found: ../data/block_logs/2023/2023-11.csv.gz
# File not found: ../data/block_logs/2023/2023-12.csv
# File not found: ../data/block_logs/2023/2023-12.csv.gz

# %% [markdown]
# The code below write the list of administrator names into a json file. Please uncomment to test it.

# %%
# import json

# # Convert and write JSON object to a gzip-compressed file
# with open("../data/processed_data/administrator_names.json", "wt") as outfile:
#     json.dump(admin_names, outfile)

# %% [markdown]
# # Identify administrator bots

# %% [markdown]
# Use list comprehension to identify names that might be a Wikipedia Bot.

# %%
[name for name in admin_names if 'bot' in str(name).lower()]
# Out:
# ['User:Botley Brewery',
#  'User:Lynyabbribot',
#  'EgressBot',
#  'User:WikiEditBot550',
#  'AnomieBOT III',
#  'AntiAbuseBot',
#  'ST47ProxyBot',
#  'NinjaRobotPirate',
#  'ProcseeBot',
#  'User:Shmuelisabot123',
#  'Water Bottle',
#  'TorNodeBot',
#  'ListManBot']

# %% [markdown]
# I searched all the above names on Wikipedia to identify bots.

# %% [markdown]
# These are identified bots:
# - [ProcseeBot](https://en.wikipedia.org/wiki/Wikipedia:Bots/Requests_for_approval/ProcseeBot)
# - [ListManBot](https://en.wikipedia.org/wiki/Wikipedia:Bots/Requests_for_approval/ListManBot)
# - [AnomieBOT III](https://en.wikipedia.org/wiki/Wikipedia:Bots/Requests_for_approval/AnomieBOT_III)
# - [AntiAbuseBot](https://en.wikipedia.org/wiki/Wikipedia:Bots/Requests_for_approval/AntiAbuseBot)
# - [EgressBot](https://en.wikipedia.org/wiki/User:EgressBot)
# - [TorNodeBot](https://en.wikipedia.org/wiki/Wikipedia:Bots/Requests_for_approval/TorNodeBot)
# - [ST47ProxyBot](https://en.wikipedia.org/wiki/Wikipedia:Bots/Requests_for_approval/ST47ProxyBot)

# %%
administrator_bots = [
    'ProcseeBot', 'ListManBot', 'AnomieBOT III', 'AntiAbuseBot',
    'EgressBot', 'TorNodeBot', 'ST47ProxyBot'
    ]

# %% [markdown]
# # Fetch editors who are bots from Wikipedia API

# %% [markdown]
# The code below shows how I fectch users that are bots from Wikipedia API.

# %%
import requests
import pandas as pd

# %%
url = "https://en.wikipedia.org/w/api.php"

parameters = {
    "action": "query",
    "format": "json",
    "list": "allusers",
    "aulimit": "500",
    "augroup": "bot", # This parameter limits the fetched users to bots
}

request_session = requests.Session()
# Send request
r = request_session.get(url=url, params=parameters)

# %%
data = r.json()
bots = data['query']['allusers']
bots_df = pd.DataFrame(bots)

# %%
bot_names = list(bots_df['name'])
bot_names
# Out:
# ["'zinbot",
#  'AAlertBot',
#  'Acebot',
#  'Addbot',
#  'AdminStatsBot',
#  'Ahechtbot',
#  'Aidan9382-Bot',
#  'AndreasJSbot',
#  'AnomieBOT',
#  'AnomieBOT II',
#  'AnomieBOT III',
#  'AntiCompositeBot',
#  'ArbClerkBot',
#  'Arbitrarily0Bot',
#  'ArmbrustBot',
#  'ArticlesForCreationBot',
#  'AttributionBot',
#  'AudeBot',
#  'AvicBot',
#  'B-bot',
#  'BD2412bot',
#  'BOTarate',
#  'BOTijo',
#  'BattyBot',
#  'Bender the Bot',
#  'Bibcode Bot',
#  'Bitbotje',
#  'BogBot',
#  'Bot1058',
#  'Bot11598',
#  'BotMultichill',
#  'BotMultichillT',
#  'BotPuppet',
#  'BrownBot',
#  'BsherrAWBBOT',
#  'BsoykaBot',
#  'ButlerBlogBot',
#  'COIBot',
#  'CanisRufus',
#  'CeraBot',
#  'Cerabot~enwiki',
#  'Cewbot',
#  'Chartbot',
#  'CheMoBot',
#  'Chem-awb',
#  'Chobot',
#  'Chris G Bot',
#  'Chris G Bot 3',
#  'ChristieBot',
#  'Citation bot',
#  'Citation bot 1',
#  'Citation bot 2',
#  'Citation bot 3',
#  'Citation bot 4',
#  'CitationCleanerBot',
#  'ClueBot II',
#  'ClueBot III',
#  'ClueBot NG',
#  'CommonsDelinker',
#  'CommonsNotificationBot',
#  'Community Tech bot',
#  'ContinuityBot',
#  'CountryBot',
#  'CrazynasBot',
#  'Cyberbot I',
#  'Cyberbot II',
#  'DPL bot',
#  'DYKHousekeepingBot',
#  'DYKToolsBot',
#  'DYKUpdateBot',
#  'DannyS712 bot',
#  'DannyS712 bot III',
#  'Dapperbot',
#  'DarafshBot',
#  'DatBot',
#  'DeadbeefBot',
#  'DeltaQuadBot',
#  'DemonDays64 Bot',
#  'DeprecatedFixerBot',
#  'Dexbot',
#  'Dreamy Jazz Bot',
#  'DumbBOT',
#  'EarwigBot',
#  'EberBot',
#  'Eejit43Bot',
#  'EmausBot',
#  'Emijrpbot',
#  'EnterpriseyBot',
#  'EranBot',
#  'ErfgoedBot',
#  'FACBot',
#  'FairuseBot',
#  'FastilyBot',
#  'Femto Bot',
#  'Filedelinkerbot',
#  'FireflyBot',
#  'FireflyBot II',
#  'Fluxbot',
#  'FrescoBot',
#  'FrostlySnowman',
#  'Gabrielchihonglee-Bot',
#  'GalliumBot',
#  'Galobot',
#  'Ganeshbot',
#  'GeneralBotability',
#  'GimmeBot',
#  'GreenC bot',
#  'H3llBot',
#  'HBC AIV helperbot',
#  'HBC AIV helperbot11',
#  'HBC AIV helperbot5',
#  'HaleBot',
#  'Harej bot',
#  'Hazard-Bot',
#  'Helpful Pixie Bot',
#  'Hmainsbot1',
#  'HostBot',
#  'HotArticlesBot',
#  'HtonlBot',
#  'ImageRemovalBot',
#  'ImageTaggingBot',
#  'InceptionBot',
#  'IndentBot',
#  'InfoboxBot',
#  'IngenuityBot',
#  'InternetArchiveBot',
#  'Italic title bot',
#  'IznoBot',
#  'J Milburn Bot',
#  'JAnDbot',
#  'JBradley Bot',
#  'JCW-CleanerBot',
#  'JCbot',
#  'JJMC89 bot',
#  'JJMC89 bot II',
#  'JJMC89 bot III',
#  'JL-Bot',
#  'JVbot',
#  'JamietwBot',
#  'JeffGBot',
#  'JhealdBot',
#  "Joe's Null Bot",
#  "Joe's Olympic Bot",
#  'John of Reading Bot',
#  'Josvebot',
#  'KMLbot',
#  'KaldariBot',
#  'KingpinBot',
#  'KiranBOT',
#  'KolbertBot',
#  'Krdbot',
#  'Legobot',
#  'ListManBot',
#  'ListeriaBot',
#  'LivingBot',
#  'Lowercase sigmabot',
#  'Lowercase sigmabot II',
#  'Lowercase sigmabot III',
#  'Luasóg bot',
#  'Lucasbfrbot',
#  'MBisanzBot',
#  'MDanielsBot',
#  'Magic links bot',
#  'Maintenance script',
#  'MajavahBot',
#  'MandelBot',
#  'Manishbot',
#  'Mathbot',
#  'Mdann52 IMG bot',
#  'Mdann52 bot',
#  'MediaWiki default',
#  'MediaWiki message delivery',
#  'MenoBot',
#  'MenoBot II',
#  'Merge bot',
#  'MifterBot',
#  'MifterBot I',
#  'MilHistBot',
#  'MinusBot',
#  'Monkbot',
#  'MoohanBOT',
#  'MuZebot',
#  'Muhbot',
#  'Muninnbot',
#  'MusikBot',
#  'MusikBot II',
#  'Mz7 (bot)',
#  'NationalRegisterBot',
#  'NihiltresBot',
#  'NovemBot',
#  'NukeBot',
#  'OAbot',
#  'OgreBot',
#  'Ohms Law Bot',
#  'OutreachDashboardBot',
#  'PearBOT',
#  'PearBOT II',
#  'Petan-Bot',
#  'Philosopher-Bot',
#  'PhotoCatBot',
#  'Pi bot',
#  'PkbwcgsBot',
#  'Portal box bot',
#  'PotatoBot',
#  'PowerBOT',
#  'PrimeBOT',
#  'ProcBot',
#  'ProcBot II',
#  'ProcseeBot',
#  'Qbugbot',
#  'Qwerfjkl (bot)',
#  'RMCD bot',
#  'RagesossBot',
#  'Ramaksoud2000Bot',
#  'Reedy Bot',
#  'Reports bot',
#  'RetractionBot',
#  'RichBot',
#  'Rick Bot',
#  'RileyBot',
#  'RjwilmsiBot',
#  'Rlink2 Bot',
#  'RockfangBot',
#  'RottenBot',
#  'RscprinterBot',
#  'RussBot',
#  'SD5bot',
#  'SDPatrolBot',
#  'SDPatrolBot II',
#  'SDZeroBot',
#  'SPPatrolBot',
#  'SSTbot',
#  'ST47Bot',
#  'ST47ProxyBot',
#  'SatyrBot',
#  'Scsbot',
#  'SdkbBot',
#  'Seppi333Bot',
#  'SheepLinterBot',
#  'ShortDescBot',
#  'SimplexityBot',
#  'SineBot',
#  'Snowbot',
#  'SpaceFactsBot',
#  'SporkBot',
#  'SportsStatsBot',
#  'Stefan2bot',
#  'SteveBot',
#  'StradBot',
#  'Stwalkerbot',
#  'SuggestBot',
#  'SvickBOT',
#  'TFA Protector Bot',
#  'TNTBot',
#  'TPBot',
#  'TTObot',
#  'TWLBot',
#  'TedderBot',
#  'Texvc2LaTeXBot',
#  'Thadius856AWB',
#  'The Anomebot2',
#  'The Sky Bot',
#  'The wubbot',
#  'TheCowBot',
#  'TheMagikBOT',
#  'TheSandBot',
#  'Thehelpfulbot',
#  'TokenzeroBot',
#  'TolBot',
#  "Tom's Tagging Bot",
#  'Tom.Bot',
#  'TowBot',
#  'TweetCiteBot',
#  'UTRSBot',
#  'UcuchaBot',
#  'UsuallyNonviolentBot',
#  'VIAFbot',
#  'VRTS Migration Bot',
#  'VWBot',
#  'VahurzpuBot',
#  'VeblenBot',
#  'VoABot',
#  'VulpesBot',
#  'WOSlinkerBot',
#  'WP 1.0 bot',
#  'WaldirBot',
#  'WebCiteBOT',
#  'WegweiserBot',
#  'WikiCleanerBot',
#  'WikiProject Notification Service',
#  'WildBot',
#  'William Avery Bot',
#  'WoodwardBot',
#  'WugBot',
#  'WxBot',
#  'Xphoisbot',
#  'Xqbot',
#  'Yapperbot',
#  'Yet another TfD implementor bot',
#  'YiFeiBot',
#  'Yobot',
#  'ZackBot']

# %% [markdown]
# # Combine & save two bot lists

# %%
all_bot_names = list(set(administrator_bots).union(set(bot_names)))

# %%
all_bot_names
# Out:
# ['TokenzeroBot',
#  'BOTijo',
#  'JJMC89 bot III',
#  'Bot11598',
#  'Cerabot~enwiki',
#  'Luasóg bot',
#  'AnomieBOT III',
#  'AndreasJSbot',
#  'SineBot',
#  'MuZebot',
#  'SportsStatsBot',
#  'RscprinterBot',
#  'AttributionBot',
#  'WxBot',
#  'SDPatrolBot II',
#  'NihiltresBot',
#  'TorNodeBot',
#  'ImageRemovalBot',
#  'NukeBot',
#  'FastilyBot',
#  'John of Reading Bot',
#  'TowBot',
#  'JJMC89 bot',
#  'Eejit43Bot',
#  'JL-Bot',
#  'Legobot',
#  'MilHistBot',
#  'TWLBot',
#  'Monkbot',
#  'DYKUpdateBot',
#  'RottenBot',
#  'FACBot',
#  'ErfgoedBot',
#  'MenoBot II',
#  'JeffGBot',
#  'Acebot',
#  'CommonsNotificationBot',
#  "'zinbot",
#  'JhealdBot',
#  'Muninnbot',
#  'VahurzpuBot',
#  'EnterpriseyBot',
#  'Galobot',
#  "Joe's Null Bot",
#  'The Sky Bot',
#  'HotArticlesBot',
#  'SDZeroBot',
#  'Citation bot 2',
#  'ClueBot II',
#  'NovemBot',
#  'DeadbeefBot',
#  'ClueBot III',
#  'Muhbot',
#  'DarafshBot',
#  'WebCiteBOT',
#  'AudeBot',
#  'PowerBOT',
#  'Fluxbot',
#  'WP 1.0 bot',
#  'BOTarate',
#  'MinusBot',
#  'OgreBot',
#  'ZackBot',
#  'TolBot',
#  'UsuallyNonviolentBot',
#  'ST47Bot',
#  'RagesossBot',
#  'Manishbot',
#  'Dexbot',
#  'ArbClerkBot',
#  'Qwerfjkl (bot)',
#  'MediaWiki message delivery',
#  'Reedy Bot',
#  'Chris G Bot',
#  'ChristieBot',
#  'Yapperbot',
#  'KaldariBot',
#  'PrimeBOT',
#  'Community Tech bot',
#  'Ganeshbot',
#  'UcuchaBot',
#  'MoohanBOT',
#  'DYKToolsBot',
#  'AntiCompositeBot',
#  'KolbertBot',
#  'VIAFbot',
#  'JCbot',
#  'SimplexityBot',
#  'MifterBot',
#  'RockfangBot',
#  'VulpesBot',
#  'Citation bot 1',
#  'TPBot',
#  'Chobot',
#  'Citation bot',
#  'Tom.Bot',
#  'InternetArchiveBot',
#  'KiranBOT',
#  'DeprecatedFixerBot',
#  'WikiProject Notification Service',
#  'ProcBot II',
#  'ContinuityBot',
#  'EberBot',
#  'MandelBot',
#  'Emijrpbot',
#  'Philosopher-Bot',
#  'StradBot',
#  'KMLbot',
#  'TNTBot',
#  'ButlerBlogBot',
#  'VeblenBot',
#  'Rlink2 Bot',
#  'Cyberbot I',
#  'JAnDbot',
#  'Ahechtbot',
#  'Bitbotje',
#  'DumbBOT',
#  'Stefan2bot',
#  'JCW-CleanerBot',
#  'KingpinBot',
#  'NationalRegisterBot',
#  'SDPatrolBot',
#  'Bibcode Bot',
#  'Bot1058',
#  'Mathbot',
#  'Merge bot',
#  'FireflyBot',
#  'Chartbot',
#  'Portal box bot',
#  'HBC AIV helperbot5',
#  'CountryBot',
#  'FireflyBot II',
#  'IndentBot',
#  'AnomieBOT',
#  'B-bot',
#  'TheCowBot',
#  'EgressBot',
#  'EranBot',
#  'Mz7 (bot)',
#  'Yet another TfD implementor bot',
#  'MBisanzBot',
#  'WugBot',
#  'SD5bot',
#  'DYKHousekeepingBot',
#  'Xphoisbot',
#  'Citation bot 4',
#  'FairuseBot',
#  'SdkbBot',
#  'PearBOT',
#  'CheMoBot',
#  'J Milburn Bot',
#  'Ohms Law Bot',
#  'WegweiserBot',
#  'AntiAbuseBot',
#  'Bender the Bot',
#  'Texvc2LaTeXBot',
#  'PhotoCatBot',
#  'Dapperbot',
#  'RichBot',
#  'Petan-Bot',
#  'SpaceFactsBot',
#  'Gabrielchihonglee-Bot',
#  'FrescoBot',
#  "Tom's Tagging Bot",
#  'MajavahBot',
#  'CanisRufus',
#  'JJMC89 bot II',
#  'WaldirBot',
#  'Chem-awb',
#  'ArticlesForCreationBot',
#  'Maintenance script',
#  'UTRSBot',
#  'InceptionBot',
#  'CeraBot',
#  'Yobot',
#  'BsherrAWBBOT',
#  'Mdann52 bot',
#  'SSTbot',
#  'TheSandBot',
#  'Krdbot',
#  'PearBOT II',
#  'Xqbot',
#  'WikiCleanerBot',
#  'TTObot',
#  'GeneralBotability',
#  'JVbot',
#  'InfoboxBot',
#  'AdminStatsBot',
#  'SuggestBot',
#  'CrazynasBot',
#  'FrostlySnowman',
#  'Seppi333Bot',
#  'DeltaQuadBot',
#  'SvickBOT',
#  'IngenuityBot',
#  'CitationCleanerBot',
#  'Hmainsbot1',
#  'RMCD bot',
#  'Arbitrarily0Bot',
#  'Lucasbfrbot',
#  'HBC AIV helperbot11',
#  'HBC AIV helperbot',
#  'ImageTaggingBot',
#  'TheMagikBOT',
#  'WOSlinkerBot',
#  'RjwilmsiBot',
#  'Hazard-Bot',
#  'Lowercase sigmabot II',
#  'OAbot',
#  'VRTS Migration Bot',
#  'EmausBot',
#  'Addbot',
#  'H3llBot',
#  'Filedelinkerbot',
#  'Scsbot',
#  'Thadius856AWB',
#  'Stwalkerbot',
#  'BrownBot',
#  'WoodwardBot',
#  'JamietwBot',
#  'Cyberbot II',
#  'BsoykaBot',
#  'Ramaksoud2000Bot',
#  'RussBot',
#  'EarwigBot',
#  'GreenC bot',
#  'The Anomebot2',
#  'ProcBot',
#  'HostBot',
#  'IznoBot',
#  'MifterBot I',
#  'MDanielsBot',
#  'YiFeiBot',
#  'DPL bot',
#  'DannyS712 bot',
#  'PkbwcgsBot',
#  'AvicBot',
#  'LivingBot',
#  'The wubbot',
#  'TFA Protector Bot',
#  'DatBot',
#  'William Avery Bot',
#  'HaleBot',
#  'BotPuppet',
#  'Lowercase sigmabot III',
#  'Josvebot',
#  'ShortDescBot',
#  'MusikBot',
#  'ST47ProxyBot',
#  'BotMultichill',
#  'GimmeBot',
#  'Chris G Bot 3',
#  'Citation bot 3',
#  'CommonsDelinker',
#  'ArmbrustBot',
#  'MusikBot II',
#  'AAlertBot',
#  'Rick Bot',
#  'Harej bot',
#  'RetractionBot',
#  'BD2412bot',
#  'COIBot',
#  'Qbugbot',
#  'RileyBot',
#  'ListeriaBot',
#  'BotMultichillT',
#  'BattyBot',
#  'SatyrBot',
#  'ListManBot',
#  'SteveBot',
#  'PotatoBot',
#  'Mdann52 IMG bot',
#  'VoABot',
#  'DannyS712 bot III',
#  'Reports bot',
#  'SheepLinterBot',
#  'OutreachDashboardBot',
#  'Magic links bot',
#  'ClueBot NG',
#  'Femto Bot',
#  "Joe's Olympic Bot",
#  'SporkBot',
#  'Lowercase sigmabot',
#  'SPPatrolBot',
#  'AnomieBOT II',
#  'MediaWiki default',
#  'MenoBot',
#  'BogBot',
#  'Dreamy Jazz Bot',
#  'Cewbot',
#  'Snowbot',
#  'VWBot',
#  'Thehelpfulbot',
#  'Aidan9382-Bot',
#  'Italic title bot',
#  'TedderBot',
#  'TweetCiteBot',
#  'ProcseeBot',
#  'DemonDays64 Bot',
#  'HtonlBot',
#  'GalliumBot',
#  'Helpful Pixie Bot',
#  'JBradley Bot',
#  'Pi bot',
#  'WildBot']

# %% [markdown]
# The code below write the list of bot names into a json file. Please uncomment to test it.

# %%
# import json

# # Convert and write JSON object
# with open("../data/scraped_data_metrics/bot_names.json", "wt") as outfile:
#      json.dump(all_bot_names, outfile)
