# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook explains how to run the spider program to fetch block logs from Wikipedia API.

# %%
import requests
import pandas as pd

# %%
# append system path to import spider program
import sys
sys.path.append('../')
from utils.spiders import retrieve_block_logs_month # fetch data for a specific month in a given year
from utils.spiders import retrieve_block_logs_year # fetch data for a given year

# %% [markdown]
# # Code examples

# %% [markdown]
# ## Retrieve data for 1 month

# %% [markdown]
# To retrieve block logs for a specific month, please use the retrieve_block_logs_month function. It automatically retrieves the logs and write them into a local csv file (format: year-month.csv).
#
# It requires 4 parameters:
# - year (int):
#     - The year for which block logs should be retrieved.
# - month (int):
#     - The month for which block logs should be retrieved.
# - folder_path (str):
#     - The folder path where the CSV file will be saved.
# - compress (bool):
#     - Specify if compress the CSV file into a gz file.

# %% [markdown]
# **Note:**
# - If you encounter issues at running the function, please check if a file already exists on your local disk. This function automatically stop to prevent from overwritting local file.

# %% [markdown]
# **About runtime for data retrieval:**
# - Before August 2021: it takes around 5-10 minutes maximum to retrieve data for each month.
# - August 2021 onwards: it can take up to 30-50 minute to retrieve data for each month, even with good internet connections.

# %%
# Set folder path to store fetched data
folder_path = '../data/block_logs/'

# %%
retrieve_block_logs_month(year=2006, month=2, folder_path=folder_path, compress=False)
# Out:
# 500 records retrieved.
# Search with continue index: 20060201215221|1579465, 500 records retrieved.
# Search with continue index: 20060202151922|1586911, 500 records retrieved.
# Search with continue index: 20060203033653|1593016, 500 records retrieved.
# Search with continue index: 20060203215030|1600305, 500 records retrieved.
# Search with continue index: 20060204223431|1609446, 500 records retrieved.
# Search with continue index: 20060205215452|1618865, 500 records retrieved.
# Search with continue index: 20060206175554|1627241, 500 records retrieved.
# Search with continue index: 20060207025229|1632446, 500 records retrieved.
# Search with continue index: 20060207210849|1640608, 500 records retrieved.
# Search with continue index: 20060208035041|1644786, 500 records retrieved.
# Search with continue index: 20060208221003|1653278, 500 records retrieved.
# Search with continue index: 20060209195305|1663172, 500 records retrieved.
# Search with continue index: 20060210175418|1673158, 500 records retrieved.
# Search with continue index: 20060211175654|1682260, 500 records retrieved.
# Search with continue index: 20060212131851|1690481, 500 records retrieved.
# Search with continue index: 20060213003838|1696416, 500 records retrieved.
# Search with continue index: 20060214014402|1704099, 500 records retrieved.
# Search with continue index: 20060214163536|1710238, 500 records retrieved.
# Search with continue index: 20060215031436|1715900, 500 records retrieved.
# Search with continue index: 20060215051122|1717367, 500 records retrieved.
# Search with continue index: 20060215080834|1719227, 500 records retrieved.
# Search with continue index: 20060216040645|1729404, 500 records retrieved.
# Search with continue index: 20060217031339|1739493, 500 records retrieved.
# Search with continue index: 20060218054743|1751446, 500 records retrieved.
# Search with continue index: 20060219033953|1762296, 500 records retrieved.
# Search with continue index: 20060220090201|1774832, 500 records retrieved.
# Search with continue index: 20060221055746|1784086, 500 records retrieved.
# Search with continue index: 20060222160120|1797941, 500 records retrieved.
# Search with continue index: 20060223154223|1808828, 500 records retrieved.
# Search with continue index: 20060224050919|1815891, 500 records retrieved.
# Search with continue index: 20060224054040|1816674, 500 records retrieved.
# Search with continue index: 20060225002153|1824923, 500 records retrieved.
# Search with continue index: 20060226222236|1844488, 500 records retrieved.
# Search with continue index: 20060227040200|1847822, 500 records retrieved.
# Search with continue index: 20060227202110|1857034, 500 records retrieved.
# Search with continue index: 20060228171018|1867057, 379 records retrieved.
# Retrieval complete for logs between 2006-02-01T00:00:00Z and 2006-03-01T00:00:00Z.
# 18379 records retrieved.

# %% [markdown]
# ## Retrieve data for 1 year

# %% [markdown]
# To retrieve block logs for a specific year, please use the retrieve_block_logs_month function. It automatically loops over the month retrive function to download and store logs for a given year. The data will be stored in 12 local csv files (format: year-month.csv), each for 1 month.
#
# It requires 3 parameters:
# - year (int):
#     - The year for which block logs should be retrieved.
# - folder_path (str):
#     - The folder path where the CSV file will be saved.
# - compress (bool):
#     - Specify if compress the CSV file into a gz file.

# %% [markdown]
# **Recommendations**:
# - I advise against running this function to scrape yearly data for 2022 and onwards within one go. It can take several hours to scrape all data.

# %% [markdown]
# **Note:**
# - If you encounter issues at running the function, please check if a file already exists on your local disk. This function automatically stop to prevent from overwritting local file.

# %%
# Set folder path to store fetched data
folder_path = '../data/block_logs/'

# %%
for i in range(2016, 2021, 1):
    retrieve_block_logs_year(year=i, folder_path=folder_path, compress=True)
# Out:
# 500 records retrieved.
# Search with continue index: 20160101200219|71517014, 500 records retrieved.
# Search with continue index: 20160102154016|71532524, 500 records retrieved.
# Search with continue index: 20160103075145|71546824, 500 records retrieved.
# Search with continue index: 20160103171210|71554888, 500 records retrieved.
# Search with continue index: 20160104051308|71565952, 500 records retrieved.
# Search with continue index: 20160104230809|71584008, 500 records retrieved.
# Search with continue index: 20160105071023|71593213, 500 records retrieved.
# Search with continue index: 20160105234912|71610065, 500 records retrieved.
# Search with continue index: 20160106151207|71624199, 500 records retrieved.
# Search with continue index: 20160107000805|71633974, 500 records retrieved.
# Search with continue index: 20160107151311|71646454, 500 records retrieved.
# Search with continue index: 20160108010807|71657180, 500 records retrieved.
# Search with continue index: 20160108061856|71661457, 500 records retrieved.
# Search with continue index: 20160108165904|71670769, 500 records retrieved.
# Search with continue index: 20160108230919|71677318, 500 records retrieved.
# Search with continue index: 20160109031615|71681019, 500 records retrieved.
# Search with continue index: 20160109164643|71690958, 500 records retrieved.
# Search with continue index: 20160109231316|71697239, 500 records retrieved.
# Search with continue index: 20160109232830|71697937, 500 records retrieved.
# Search with continue index: 20160110021320|71700951, 500 records retrieved.
# Search with continue index: 20160110121215|71708978, 500 records retrieved.
# Search with continue index: 20160110151217|71712165, 500 records retrieved.
# Search with continue index: 20160110191001|71716900, 500 records retrieved.
# Search with continue index: 20160110210937|71719522, 500 records retrieved.
# Search with continue index: 20160111020810|71724779, 500 records retrieved.
# Search with continue index: 20160111111303|71733292, 500 records retrieved.
# Search with continue index: 20160111181907|71740917, 500 records retrieved.
# Search with continue index: 20160111220819|71745459, 500 records retrieved.
# Search with continue index: 20160112001601|71747777, 500 records retrieved.
# Search with continue index: 20160112060800|71753324, 500 records retrieved.
# Search with continue index: 20160112120829|71758334, 500 records retrieved.
# Search with continue index: 20160112200126|71767065, 500 records retrieved.
# Search with continue index: 20160112221119|71771086, 500 records retrieved.
# Search with continue index: 20160113015457|71774635, 500 records retrieved.
# Search with continue index: 20160113080942|71779854, 500 records retrieved.
# Search with continue index: 20160113120800|71783092, 500 records retrieved.
# Search with continue index: 20160113170801|71788395, 500 records retrieved.
# Search with continue index: 20160113225507|71794491, 500 records retrieved.
# Search with continue index: 20160114060818|71801274, 500 records retrieved.
# Search with continue index: 20160114141304|71807144, 500 records retrieved.
# Search with continue index: 20160114212138|71815237, 500 records retrieved.
# Search with continue index: 20160115100102|71825493, 500 records retrieved.
# Search with continue index: 20160115201006|71835828, 500 records retrieved.
# Search with continue index: 20160116042511|71843155, 500 records retrieved.
# Search with continue index: 20160116211709|71859641, 500 records retrieved.
# Search with continue index: 20160117110840|71872080, 500 records retrieved.
# Search with continue index: 20160117171001|71878770, 500 records retrieved.
# Search with continue index: 20160117212905|71883580, 500 records retrieved.
# Search with continue index: 20160118080907|71895863, 500 records retrieved.
# Search with continue index: 20160118193445|71908624, 500 records retrieved.
# Search with continue index: 20160119040038|71919284, 500 records retrieved.
# Search with continue index: 20160119155223|71930645, 500 records retrieved.
# Search with continue index: 20160120020818|71943394, 500 records retrieved.
# Search with continue index: 20160120140807|71953344, 500 records retrieved.
# Search with continue index: 20160120142209|71954103, 500 records retrieved.
# Search with continue index: 20160120144814|71955085, 500 records retrieved.
# Search with continue index: 20160120150451|71955836, 500 records retrieved.
# Search with continue index: 20160120193546|71961419, 500 records retrieved.
# Search with continue index: 20160120232101|71966432, 500 records retrieved.
# Search with continue index: 20160121130759|71977972, 500 records retrieved.
# Search with continue index: 20160121160941|71981655, 500 records retrieved.
# Search with continue index: 20160121162518|71982483, 500 records retrieved.
# Search with continue index: 20160121220910|71990258, 500 records retrieved.
# Search with continue index: 20160122001631|71992734, 500 records retrieved.
# Search with continue index: 20160122084821|71999964, 500 records retrieved.
# Search with continue index: 20160122144640|72004814, 500 records retrieved.
# Search with continue index: 20160122220820|72012247, 500 records retrieved.
# Search with continue index: 20160123004107|72014652, 500 records retrieved.
# Search with continue index: 20160123151304|72025836, 500 records retrieved.
# Search with continue index: 20160124021303|72038290, 500 records retrieved.
# Search with continue index: 20160124121307|72045356, 500 records retrieved.
# Search with continue index: 20160124140947|72047337, 500 records retrieved.
# Search with continue index: 20160125020806|72059027, 500 records retrieved.
# Search with continue index: 20160125070921|72063770, 500 records retrieved.
# Search with continue index: 20160125170820|72072364, 500 records retrieved.
# Search with continue index: 20160125220126|72078571, 500 records retrieved.
# Search with continue index: 20160126032052|72083834, 500 records retrieved.
# Search with continue index: 20160126140842|72092521, 500 records retrieved.
# Search with continue index: 20160126190823|72098412, 500 records retrieved.
# Search with continue index: 20160126192200|72099189, 500 records retrieved.
# Search with continue index: 20160126221608|72104119, 500 records retrieved.
# Search with continue index: 20160126222954|72104775, 500 records retrieved.
# Search with continue index: 20160126224814|72105573, 500 records retrieved.
# Search with continue index: 20160126230150|72106272, 500 records retrieved.
# Search with continue index: 20160126232011|72107011, 500 records retrieved.
# Search with continue index: 20160126233409|72107691, 500 records retrieved.
# Search with continue index: 20160126235212|72108386, 500 records retrieved.
# Search with continue index: 20160127000543|72109046, 500 records retrieved.
# Search with continue index: 20160127002039|72109747, 500 records retrieved.
# Search with continue index: 20160127003420|72110410, 500 records retrieved.
# Search with continue index: 20160127075949|72117146, 500 records retrieved.
# Search with continue index: 20160127134224|72121973, 500 records retrieved.
# Search with continue index: 20160127221156|72131464, 500 records retrieved.
# Search with continue index: 20160128103812|72142358, 500 records retrieved.
# Search with continue index: 20160128215810|72153854, 500 records retrieved.
# Search with continue index: 20160129080824|72162601, 500 records retrieved.
# Search with continue index: 20160129082503|72163234, 500 records retrieved.
# Search with continue index: 20160129084023|72163888, 500 records retrieved.
# Search with continue index: 20160129091633|72164664, 500 records retrieved.
# Search with continue index: 20160129152440|72169542, 500 records retrieved.
# Search with continue index: 20160129215404|72176458, 500 records retrieved.
# Search with continue index: 20160130064911|72183655, 500 records retrieved.
# Search with continue index: 20160130221304|72197795, 500 records retrieved.
# Search with continue index: 20160131011616|72200998, 500 records retrieved.
# Search with continue index: 20160131112412|72208290, 371 records retrieved.
# Retrieval complete for logs between 2016-01-01T00:00:00Z and 2016-02-01T00:00:00Z.
# 52871 records retrieved.
# 500 records retrieved.
# Search with continue index: 20160201100759|72228370, 500 records retrieved.
# Search with continue index: 20160201202858|72239429, 500 records retrieved.
# Search with continue index: 20160202040813|72247974, 500 records retrieved.
# Search with continue index: 20160202100759|72253152, 500 records retrieved.
# Search with continue index: 20160202161307|72260309, 500 records retrieved.
# Search with continue index: 20160202222220|72268318, 500 records retrieved.
# Search with continue index: 20160203091742|72278736, 500 records retrieved.
# Search with continue index: 20160203203818|72291344, 500 records retrieved.
# Search with continue index: 20160204060756|72300331, 500 records retrieved.
# Search with continue index: 20160204172220|72310263, 500 records retrieved.
# Search with continue index: 20160205011259|72319146, 500 records retrieved.
# Search with continue index: 20160205152624|72330550, 500 records retrieved.
# Search with continue index: 20160205232713|72338856, 500 records retrieved.
# Search with continue index: 20160206152936|72350894, 500 records retrieved.
# Search with continue index: 20160207040425|72362153, 500 records retrieved.
# Search with continue index: 20160207210803|72376545, 500 records retrieved.
# Search with continue index: 20160208123613|72390435, 500 records retrieved.
# Search with continue index: 20160208211712|72401227, 500 records retrieved.
# Search with continue index: 20160209060758|72410145, 500 records retrieved.
# Search with continue index: 20160209174306|72420107, 500 records retrieved.
# Search with continue index: 20160210011315|72427845, 500 records retrieved.
# Search with continue index: 20160210165153|72441418, 500 records retrieved.
# Search with continue index: 20160211031259|72452607, 500 records retrieved.
# Search with continue index: 20160211162056|72463514, 500 records retrieved.
# Search with continue index: 20160211221154|72470079, 500 records retrieved.
# Search with continue index: 20160212111243|72480339, 500 records retrieved.
# Search with continue index: 20160212203832|72489606, 500 records retrieved.
# Search with continue index: 20160213102535|72500135, 500 records retrieved.
# Search with continue index: 20160214003639|72514007, 500 records retrieved.
# Search with continue index: 20160214201303|72531585, 500 records retrieved.
# Search with continue index: 20160215113153|72543951, 500 records retrieved.
# Search with continue index: 20160215231315|72556988, 500 records retrieved.
# Search with continue index: 20160216062339|72563725, 500 records retrieved.
# Search with continue index: 20160216181333|72574405, 500 records retrieved.
# Search with continue index: 20160217023312|72583303, 500 records retrieved.
# Search with continue index: 20160217160541|72595815, 500 records retrieved.
# Search with continue index: 20160217230755|72604639, 500 records retrieved.
# Search with continue index: 20160218134238|72617604, 500 records retrieved.
# Search with continue index: 20160218171744|72621497, 500 records retrieved.
# Search with continue index: 20160218215957|72626701, 500 records retrieved.
# Search with continue index: 20160219043734|72632585, 500 records retrieved.
# Search with continue index: 20160219164152|72642926, 500 records retrieved.
# Search with continue index: 20160220021300|72651776, 500 records retrieved.
# Search with continue index: 20160220191300|72665279, 500 records retrieved.
# Search with continue index: 20160221074416|72676172, 500 records retrieved.
# Search with continue index: 20160221221358|72689840, 500 records retrieved.
# Search with continue index: 20160222142017|72703526, 500 records retrieved.
# Search with continue index: 20160222221253|72712141, 500 records retrieved.
# Search with continue index: 20160223074926|72721176, 500 records retrieved.
# Search with continue index: 20160223182549|72730714, 500 records retrieved.
# Search with continue index: 20160224021256|72739101, 500 records retrieved.
# Search with continue index: 20160224144626|72750150, 500 records retrieved.
# Search with continue index: 20160224234558|72761902, 500 records retrieved.
# Search with continue index: 20160225125644|72772740, 500 records retrieved.
# Search with continue index: 20160225214740|72782820, 500 records retrieved.
# Search with continue index: 20160226031302|72788061, 500 records retrieved.
# Search with continue index: 20160226070131|72791522, 500 records retrieved.
# Search with continue index: 20160226141555|72797849, 500 records retrieved.
# Search with continue index: 20160226184350|72803081, 500 records retrieved.
# Search with continue index: 20160227010805|72826029, 500 records retrieved.
# Search with continue index: 20160227064350|72830366, 500 records retrieved.
# Search with continue index: 20160227191252|72841128, 500 records retrieved.
# Search with continue index: 20160228101305|72853159, 500 records retrieved.
# Search with continue index: 20160228235253|72866765, 500 records retrieved.
# Search with continue index: 20160229163158|72881747, 500 records retrieved.
# Search with continue index: 20160229230750|72889956, 57 records retrieved.
# Retrieval complete for logs between 2016-02-01T00:00:00Z and 2016-03-01T00:00:00Z.
# 33057 records retrieved.
# 500 records retrieved.
# Search with continue index: 20160301131255|72901667, 500 records retrieved.
# Search with continue index: 20160302001252|72915227, 500 records retrieved.
# Search with continue index: 20160302094253|72923102, 500 records retrieved.
# Search with continue index: 20160302180757|72931189, 500 records retrieved.
# Search with continue index: 20160302210821|72935684, 500 records retrieved.
# Search with continue index: 20160303011713|72941431, 500 records retrieved.
# Search with continue index: 20160303041255|72943996, 500 records retrieved.
# Search with continue index: 20160303091552|72948022, 500 records retrieved.
# Search with continue index: 20160303173149|72955957, 500 records retrieved.
# Search with continue index: 20160304011258|72963641, 500 records retrieved.
# Search with continue index: 20160304090928|72970110, 500 records retrieved.
# Search with continue index: 20160304092805|72970824, 500 records retrieved.
# Search with continue index: 20160304094358|72971488, 500 records retrieved.
# Search with continue index: 20160304110804|72973025, 500 records retrieved.
# Search with continue index: 20160304151151|72977245, 500 records retrieved.
# Search with continue index: 20160304221606|72984677, 500 records retrieved.
# Search with continue index: 20160305095950|72993422, 500 records retrieved.
# Search with continue index: 20160305210749|73004112, 500 records retrieved.
# Search with continue index: 20160306131303|73017659, 500 records retrieved.
# Search with continue index: 20160307011652|73029972, 500 records retrieved.
# Search with continue index: 20160307153251|73041799, 500 records retrieved.
# Search with continue index: 20160307232855|73051072, 500 records retrieved.
# Search with continue index: 20160308111254|73059982, 500 records retrieved.
# Search with continue index: 20160308201259|73072528, 500 records retrieved.
# Search with continue index: 20160309051251|73084096, 500 records retrieved.
# Search with continue index: 20160309181255|73099964, 500 records retrieved.
# Search with continue index: 20160310023248|73111057, 500 records retrieved.
# Search with continue index: 20160310094959|73119078, 500 records retrieved.
# Search with continue index: 20160310141611|73124280, 500 records retrieved.
# Search with continue index: 20160310143609|73125170, 500 records retrieved.
# Search with continue index: 20160310145212|73126014, 500 records retrieved.
# Search with continue index: 20160310150900|73126895, 500 records retrieved.
# Search with continue index: 20160310152806|73127799, 500 records retrieved.
# Search with continue index: 20160310180809|73131506, 500 records retrieved.
# Search with continue index: 20160310235907|73139293, 500 records retrieved.
# Search with continue index: 20160311110749|73151246, 500 records retrieved.
# Search with continue index: 20160311212050|73163940, 500 records retrieved.
# Search with continue index: 20160312050750|73172510, 500 records retrieved.
# Search with continue index: 20160312183312|73188376, 500 records retrieved.
# Search with continue index: 20160313021552|73197306, 500 records retrieved.
# Search with continue index: 20160313150758|73211919, 500 records retrieved.
# Search with continue index: 20160314030751|73227414, 500 records retrieved.
# Search with continue index: 20160314160757|73241722, 500 records retrieved.
# Search with continue index: 20160315000604|73251620, 500 records retrieved.
# Search with continue index: 20160315081303|73259115, 500 records retrieved.
# Search with continue index: 20160315162053|73269488, 500 records retrieved.
# Search with continue index: 20160315230804|73279071, 500 records retrieved.
# Search with continue index: 20160316043500|73285443, 500 records retrieved.
# Search with continue index: 20160316100759|73291487, 500 records retrieved.
# Search with continue index: 20160316161408|73299519, 500 records retrieved.
# Search with continue index: 20160316210759|73306384, 500 records retrieved.
# Search with continue index: 20160317021549|73312745, 500 records retrieved.
# Search with continue index: 20160317151230|73330148, 500 records retrieved.
# Search with continue index: 20160317182004|73334855, 500 records retrieved.
# Search with continue index: 20160317210759|73338547, 500 records retrieved.
# Search with continue index: 20160318020758|73344719, 500 records retrieved.
# Search with continue index: 20160318100752|73352434, 500 records retrieved.
# Search with continue index: 20160318200042|73363139, 500 records retrieved.
# Search with continue index: 20160319002200|73368640, 500 records retrieved.
# Search with continue index: 20160319091255|73377855, 500 records retrieved.
# Search with continue index: 20160319201555|73391201, 500 records retrieved.
# Search with continue index: 20160320060817|73402153, 500 records retrieved.
# Search with continue index: 20160320183641|73416296, 500 records retrieved.
# Search with continue index: 20160321051547|73428720, 500 records retrieved.
# Search with continue index: 20160321171550|73441367, 500 records retrieved.
# Search with continue index: 20160322005023|73450948, 500 records retrieved.
# Search with continue index: 20160322132008|73464212, 500 records retrieved.
# Search with continue index: 20160322181559|73470858, 500 records retrieved.
# Search with continue index: 20160322225415|73477389, 500 records retrieved.
# Search with continue index: 20160323081249|73487835, 500 records retrieved.
# Search with continue index: 20160323143656|73495128, 500 records retrieved.
# Search with continue index: 20160323221546|73505379, 500 records retrieved.
# Search with continue index: 20160324081312|73513050, 500 records retrieved.
# Search with continue index: 20160324150750|73519054, 500 records retrieved.
# Search with continue index: 20160324200827|73525514, 500 records retrieved.
# Search with continue index: 20160325041249|73534029, 500 records retrieved.
# Search with continue index: 20160325130753|73542156, 500 records retrieved.
# Search with continue index: 20160325180930|73548097, 500 records retrieved.
# Search with continue index: 20160325182810|73548939, 500 records retrieved.
# Search with continue index: 20160325195435|73551152, 500 records retrieved.
# Search with continue index: 20160326021250|73557238, 500 records retrieved.
# Search with continue index: 20160326120745|73565389, 500 records retrieved.
# Search with continue index: 20160326180819|73571512, 500 records retrieved.
# Search with continue index: 20160326210814|73574867, 500 records retrieved.
# Search with continue index: 20160327021300|73580277, 500 records retrieved.
# Search with continue index: 20160327140751|73589082, 500 records retrieved.
# Search with continue index: 20160327160803|73591687, 500 records retrieved.
# Search with continue index: 20160327181251|73594399, 500 records retrieved.
# Search with continue index: 20160327191602|73595943, 500 records retrieved.
# Search with continue index: 20160328041250|73603897, 500 records retrieved.
# Search with continue index: 20160328113907|73609522, 500 records retrieved.
# Search with continue index: 20160328132011|73611552, 500 records retrieved.
# Search with continue index: 20160328141606|73612838, 500 records retrieved.
# Search with continue index: 20160328175646|73616719, 500 records retrieved.
# Search with continue index: 20160328191144|73618681, 500 records retrieved.
# Search with continue index: 20160329011250|73625665, 500 records retrieved.
# Search with continue index: 20160329130811|73636435, 500 records retrieved.
# Search with continue index: 20160329160831|73640393, 500 records retrieved.
# Search with continue index: 20160329171552|73642095, 500 records retrieved.
# Search with continue index: 20160329221649|73647769, 500 records retrieved.
# Search with continue index: 20160330091546|73656107, 500 records retrieved.
# Search with continue index: 20160330150921|73661327, 500 records retrieved.
# Search with continue index: 20160330180930|73665118, 500 records retrieved.
# Search with continue index: 20160330210755|73668608, 500 records retrieved.
# Search with continue index: 20160330234307|73671590, 500 records retrieved.
# Search with continue index: 20160331011026|73673116, 500 records retrieved.
# Search with continue index: 20160331050759|73677205, 500 records retrieved.
# Search with continue index: 20160331090905|73681059, 500 records retrieved.
# Search with continue index: 20160331121615|73684079, 500 records retrieved.
# Search with continue index: 20160331160758|73688337, 500 records retrieved.
# Search with continue index: 20160331221547|73695436, 161 records retrieved.
# Retrieval complete for logs between 2016-03-01T00:00:00Z and 2016-04-01T00:00:00Z.
# 55661 records retrieved.
# 500 records retrieved.
# Search with continue index: 20160401113704|73706354, 500 records retrieved.
# Search with continue index: 20160401211117|73715239, 500 records retrieved.
# Search with continue index: 20160402091958|73724231, 500 records retrieved.
# Search with continue index: 20160402223544|73736768, 500 records retrieved.
# Search with continue index: 20160403131247|73749893, 500 records retrieved.
# Search with continue index: 20160404010748|73762312, 500 records retrieved.
# Search with continue index: 20160404134846|73773648, 500 records retrieved.
# Search with continue index: 20160404232307|73783869, 500 records retrieved.
# Search with continue index: 20160405130750|73796198, 500 records retrieved.
# Search with continue index: 20160405230745|73807823, 500 records retrieved.
# Search with continue index: 20160406121250|73821939, 500 records retrieved.
# Search with continue index: 20160406201819|73832582, 500 records retrieved.
# Search with continue index: 20160407063037|73846191, 500 records retrieved.
# Search with continue index: 20160407200743|73863243, 500 records retrieved.
# Search with continue index: 20160408064447|73873922, 500 records retrieved.
# Search with continue index: 20160408200743|73887822, 500 records retrieved.
# Search with continue index: 20160409054130|73897903, 500 records retrieved.
# Search with continue index: 20160409140759|73907177, 500 records retrieved.
# Search with continue index: 20160409221144|73917596, 500 records retrieved.
# Search with continue index: 20160410081246|73926056, 500 records retrieved.
# Search with continue index: 20160410191257|73938974, 500 records retrieved.
# Search with continue index: 20160411023430|73948176, 500 records retrieved.
# Search with continue index: 20160411151142|73965486, 500 records retrieved.
# Search with continue index: 20160411221304|73975722, 500 records retrieved.
# Search with continue index: 20160412071248|73985403, 500 records retrieved.
# Search with continue index: 20160412184342|73998677, 500 records retrieved.
# Search with continue index: 20160413011601|74006402, 500 records retrieved.
# Search with continue index: 20160413121218|74018015, 500 records retrieved.
# Search with continue index: 20160413193649|74030858, 500 records retrieved.
# Search with continue index: 20160414021248|74041105, 500 records retrieved.
# Search with continue index: 20160414155336|74060144, 500 records retrieved.
# Search with continue index: 20160415005359|74074441, 500 records retrieved.
# Search with continue index: 20160415080749|74084427, 500 records retrieved.
# Search with continue index: 20160415152929|74096409, 500 records retrieved.
# Search with continue index: 20160415223113|74107015, 500 records retrieved.
# Search with continue index: 20160416121542|74123599, 500 records retrieved.
# Search with continue index: 20160417051243|74149682, 500 records retrieved.
# Search with continue index: 20160417191248|74168990, 500 records retrieved.
# Search with continue index: 20160418082158|74184584, 500 records retrieved.
# Search with continue index: 20160418185503|74199172, 500 records retrieved.
# Search with continue index: 20160419011248|74208259, 500 records retrieved.
# Search with continue index: 20160419144915|74226966, 500 records retrieved.
# Search with continue index: 20160419230742|74240833, 500 records retrieved.
# Search with continue index: 20160420111251|74255765, 500 records retrieved.
# Search with continue index: 20160420220134|74274095, 500 records retrieved.
# Search with continue index: 20160421073140|74288224, 500 records retrieved.
# Search with continue index: 20160421180643|74304315, 500 records retrieved.
# Search with continue index: 20160421231636|74313130, 500 records retrieved.
# Search with continue index: 20160422111244|74329823, 500 records retrieved.
# Search with continue index: 20160422193724|74343192, 500 records retrieved.
# Search with continue index: 20160423003143|74351230, 500 records retrieved.
# Search with continue index: 20160423112531|74363670, 500 records retrieved.
# Search with continue index: 20160423231546|74378865, 500 records retrieved.
# Search with continue index: 20160424080742|74388060, 500 records retrieved.
# Search with continue index: 20160424212149|74407068, 500 records retrieved.
# Search with continue index: 20160425132850|74429798, 500 records retrieved.
# Search with continue index: 20160425220850|74445394, 500 records retrieved.
# Search with continue index: 20160426073306|74455381, 500 records retrieved.
# Search with continue index: 20160426194835|74469744, 500 records retrieved.
# Search with continue index: 20160427001602|74474959, 500 records retrieved.
# Search with continue index: 20160427091248|74482266, 500 records retrieved.
# Search with continue index: 20160427191247|74492487, 500 records retrieved.
# Search with continue index: 20160428031204|74500002, 500 records retrieved.
# Search with continue index: 20160428185234|74514661, 500 records retrieved.
# Search with continue index: 20160429030000|74524060, 500 records retrieved.
# Search with continue index: 20160429113730|74530366, 500 records retrieved.
# Search with continue index: 20160429191549|74538051, 500 records retrieved.
# Search with continue index: 20160430021643|74544405, 500 records retrieved.
# Search with continue index: 20160430150741|74553586, 452 records retrieved.
# Retrieval complete for logs between 2016-04-01T00:00:00Z and 2016-05-01T00:00:00Z.
# 34952 records retrieved.
# 500 records retrieved.
# Search with continue index: 20160501131130|74576888, 500 records retrieved.
# Search with continue index: 20160501221245|74586923, 500 records retrieved.
# Search with continue index: 20160502071247|74595188, 500 records retrieved.
# Search with continue index: 20160502151548|74603301, 500 records retrieved.
# Search with continue index: 20160502221259|74611558, 500 records retrieved.
# Search with continue index: 20160503071258|74619014, 500 records retrieved.
# Search with continue index: 20160503161244|74627994, 500 records retrieved.
# Search with continue index: 20160503231245|74637082, 500 records retrieved.
# Search with continue index: 20160504084718|74644948, 500 records retrieved.
# Search with continue index: 20160504181626|74660195, 500 records retrieved.
# Search with continue index: 20160505031249|74668600, 500 records retrieved.
# Search with continue index: 20160505140858|74678411, 500 records retrieved.
# Search with continue index: 20160505193616|74684298, 500 records retrieved.
# Search with continue index: 20160506090905|74697390, 500 records retrieved.
# Search with continue index: 20160506182724|74705673, 500 records retrieved.
# Search with continue index: 20160507021243|74712510, 500 records retrieved.
# Search with continue index: 20160507135340|74721576, 500 records retrieved.
# Search with continue index: 20160508005738|74737451, 500 records retrieved.
# Search with continue index: 20160508131549|74756831, 500 records retrieved.
# Search with continue index: 20160508225127|74766316, 500 records retrieved.
# Search with continue index: 20160509130241|74779753, 500 records retrieved.
# Search with continue index: 20160509214018|74789904, 500 records retrieved.
# Search with continue index: 20160510081246|74799073, 500 records retrieved.
# Search with continue index: 20160510181941|74810090, 500 records retrieved.
# Search with continue index: 20160511025603|74837087, 500 records retrieved.
# Search with continue index: 20160511132204|74845578, 500 records retrieved.
# Search with continue index: 20160511221243|74856259, 500 records retrieved.
# Search with continue index: 20160512064018|74863242, 500 records retrieved.
# Search with continue index: 20160512152135|74871200, 500 records retrieved.
# Search with continue index: 20160512231243|74880548, 500 records retrieved.
# Search with continue index: 20160513070040|74886478, 500 records retrieved.
# Search with continue index: 20160513181541|74896055, 500 records retrieved.
# Search with continue index: 20160514031537|74903456, 500 records retrieved.
# Search with continue index: 20160514181242|74914810, 500 records retrieved.
# Search with continue index: 20160515051545|74923398, 500 records retrieved.
# Search with continue index: 20160515160524|74931910, 500 records retrieved.
# Search with continue index: 20160515231543|74939063, 500 records retrieved.
# Search with continue index: 20160516091246|74946119, 500 records retrieved.
# Search with continue index: 20160516183429|74955122, 500 records retrieved.
# Search with continue index: 20160517030751|74963243, 500 records retrieved.
# Search with continue index: 20160517131537|74971006, 500 records retrieved.
# Search with continue index: 20160517230138|74981118, 500 records retrieved.
# Search with continue index: 20160518110040|74989774, 500 records retrieved.
# Search with continue index: 20160518191253|74999700, 500 records retrieved.
# Search with continue index: 20160519001536|75004845, 500 records retrieved.
# Search with continue index: 20160519131243|75015143, 500 records retrieved.
# Search with continue index: 20160519204223|75023013, 500 records retrieved.
# Search with continue index: 20160520051544|75030248, 500 records retrieved.
# Search with continue index: 20160520150039|75037774, 500 records retrieved.
# Search with continue index: 20160521011238|75045805, 500 records retrieved.
# Search with continue index: 20160521161537|75055931, 500 records retrieved.
# Search with continue index: 20160522070337|75066758, 500 records retrieved.
# Search with continue index: 20160522204632|75077257, 500 records retrieved.
# Search with continue index: 20160523111243|75087973, 500 records retrieved.
# Search with continue index: 20160523211257|75097396, 500 records retrieved.
# Search with continue index: 20160524081239|75106018, 500 records retrieved.
# Search with continue index: 20160524181545|75116239, 500 records retrieved.
# Search with continue index: 20160525034245|75124630, 500 records retrieved.
# Search with continue index: 20160525160255|75133903, 500 records retrieved.
# Search with continue index: 20160525231239|75140278, 500 records retrieved.
# Search with continue index: 20160526090737|75147431, 500 records retrieved.
# Search with continue index: 20160526160740|75153234, 500 records retrieved.
# Search with continue index: 20160526221127|75158757, 500 records retrieved.
# Search with continue index: 20160527065435|75164184, 500 records retrieved.
# Search with continue index: 20160527181544|75172761, 500 records retrieved.
# Search with continue index: 20160528021546|75178671, 500 records retrieved.
# Search with continue index: 20160528132344|75185753, 500 records retrieved.
# Search with continue index: 20160528191202|75190603, 500 records retrieved.
# Search with continue index: 20160529024040|75195758, 500 records retrieved.
# Search with continue index: 20160529121537|75201994, 500 records retrieved.
# Search with continue index: 20160529190745|75207660, 500 records retrieved.
# Search with continue index: 20160530001241|75211841, 500 records retrieved.
# Search with continue index: 20160530101238|75219994, 500 records retrieved.
# Search with continue index: 20160530182343|75227392, 500 records retrieved.
# Search with continue index: 20160531001249|75232698, 500 records retrieved.
# Search with continue index: 20160531091240|75239592, 500 records retrieved.
# Search with continue index: 20160531141549|75244621, 500 records retrieved.
# Search with continue index: 20160531213138|75252215, 237 records retrieved.
# Retrieval complete for logs between 2016-05-01T00:00:00Z and 2016-06-01T00:00:00Z.
# 39237 records retrieved.
# 500 records retrieved.
# Search with continue index: 20160601081717|75261123, 500 records retrieved.
# Search with continue index: 20160601201157|75271435, 500 records retrieved.
# Search with continue index: 20160602041537|75277923, 500 records retrieved.
# Search with continue index: 20160602144921|75287247, 500 records retrieved.
# Search with continue index: 20160602224751|75294643, 500 records retrieved.
# Search with continue index: 20160603083137|75302663, 500 records retrieved.
# Search with continue index: 20160603171247|75310416, 500 records retrieved.
# Search with continue index: 20160604020037|75317857, 500 records retrieved.
# Search with continue index: 20160604091241|75323383, 500 records retrieved.
# Search with continue index: 20160604173139|75331079, 500 records retrieved.
# Search with continue index: 20160605025148|75338280, 500 records retrieved.
# Search with continue index: 20160605113531|75344169, 500 records retrieved.
# Search with continue index: 20160605230737|75353388, 500 records retrieved.
# Search with continue index: 20160606111537|75361825, 500 records retrieved.
# Search with continue index: 20160606200822|75370191, 500 records retrieved.
# Search with continue index: 20160607061540|75378279, 500 records retrieved.
# Search with continue index: 20160607180036|75392077, 500 records retrieved.
# Search with continue index: 20160608061538|75408893, 500 records retrieved.
# Search with continue index: 20160608171131|75421644, 500 records retrieved.
# Search with continue index: 20160609025133|75429665, 500 records retrieved.
# Search with continue index: 20160609121641|75436568, 500 records retrieved.
# Search with continue index: 20160609211237|75444793, 500 records retrieved.
# Search with continue index: 20160610055601|75450687, 500 records retrieved.
# Search with continue index: 20160610171907|75460235, 500 records retrieved.
# Search with continue index: 20160611041900|75468734, 500 records retrieved.
# Search with continue index: 20160611191642|75480725, 500 records retrieved.
# Search with continue index: 20160612071237|75489747, 500 records retrieved.
# Search with continue index: 20160612153941|75495909, 500 records retrieved.
# Search with continue index: 20160613023024|75505522, 500 records retrieved.
# Search with continue index: 20160613131540|75514647, 500 records retrieved.
# Search with continue index: 20160613221549|75523864, 500 records retrieved.
# Search with continue index: 20160614072341|75531485, 500 records retrieved.
# Search with continue index: 20160614223925|75547674, 500 records retrieved.
# Search with continue index: 20160615045623|75552872, 500 records retrieved.
# Search with continue index: 20160615134555|75560056, 500 records retrieved.
# Search with continue index: 20160615231235|75569884, 500 records retrieved.
# Search with continue index: 20160616081933|75576425, 500 records retrieved.
# Search with continue index: 20160616183302|75587041, 500 records retrieved.
# Search with continue index: 20160617073132|75602062, 500 records retrieved.
# Search with continue index: 20160617182124|75614943, 500 records retrieved.
# Search with continue index: 20160617201151|75617627, 500 records retrieved.
# Search with continue index: 20160618010845|75623315, 500 records retrieved.
# Search with continue index: 20160618171536|75639883, 500 records retrieved.
# Search with continue index: 20160619091235|75653721, 500 records retrieved.
# Search with continue index: 20160619221240|75663837, 500 records retrieved.
# Search with continue index: 20160620124332|75674754, 500 records retrieved.
# Search with continue index: 20160620192658|75681307, 500 records retrieved.
# Search with continue index: 20160621082428|75690915, 500 records retrieved.
# Search with continue index: 20160621200352|75702304, 500 records retrieved.
# Search with continue index: 20160622084336|75710694, 500 records retrieved.
# Search with continue index: 20160622155131|75716565, 500 records retrieved.
# Search with continue index: 20160622231537|75723110, 500 records retrieved.
# Search with continue index: 20160623092433|75730061, 500 records retrieved.
# Search with continue index: 20160623182347|75738156, 500 records retrieved.
# Search with continue index: 20160624061131|75746901, 500 records retrieved.
# Search with continue index: 20160624141545|75752607, 500 records retrieved.
# Search with continue index: 20160624231149|75759653, 500 records retrieved.
# Search with continue index: 20160625091532|75765387, 500 records retrieved.
# Search with continue index: 20160625181512|75773757, 500 records retrieved.
# Search with continue index: 20160626001535|75778617, 500 records retrieved.
# Search with continue index: 20160626091242|75784248, 500 records retrieved.
# Search with continue index: 20160626161132|75790715, 500 records retrieved.
# Search with continue index: 20160626231237|75796588, 500 records retrieved.
# Search with continue index: 20160627081601|75802866, 500 records retrieved.
# Search with continue index: 20160627160258|75809592, 500 records retrieved.
# Search with continue index: 20160628002039|75816598, 500 records retrieved.
# Search with continue index: 20160628084029|75822623, 500 records retrieved.
# Search with continue index: 20160628183141|75832846, 500 records retrieved.
# Search with continue index: 20160629051532|75842563, 500 records retrieved.
# Search with continue index: 20160629141534|75850732, 500 records retrieved.
# Search with continue index: 20160629212001|75857205, 500 records retrieved.
# Search with continue index: 20160630082705|75865651, 500 records retrieved.
# Search with continue index: 20160630181539|75874762, 486 records retrieved.
# Retrieval complete for logs between 2016-06-01T00:00:00Z and 2016-07-01T00:00:00Z.
# 36986 records retrieved.
# 500 records retrieved.
# Search with continue index: 20160701112350|75888249, 500 records retrieved.
# Search with continue index: 20160701190734|75894815, 500 records retrieved.
# Search with continue index: 20160702070116|75904364, 500 records retrieved.
# Search with continue index: 20160702191130|75914370, 500 records retrieved.
# Search with continue index: 20160702231544|75917921, 500 records retrieved.
# Search with continue index: 20160703111131|75925530, 500 records retrieved.
# Search with continue index: 20160703191537|75932160, 500 records retrieved.
# Search with continue index: 20160704061553|75941521, 500 records retrieved.
# Search with continue index: 20160704161234|75949735, 500 records retrieved.
# Search with continue index: 20160704220746|75955481, 500 records retrieved.
# Search with continue index: 20160705040747|75959577, 500 records retrieved.
# Search with continue index: 20160705130733|75966064, 500 records retrieved.
# Search with continue index: 20160705181529|75970653, 500 records retrieved.
# Search with continue index: 20160706003208|75976019, 500 records retrieved.
# Search with continue index: 20160706071249|75980497, 500 records retrieved.
# Search with continue index: 20160706141241|75985817, 500 records retrieved.
# Search with continue index: 20160706210744|75992085, 500 records retrieved.
# Search with continue index: 20160707051534|75997983, 500 records retrieved.
# Search with continue index: 20160707145914|76005235, 500 records retrieved.
# Search with continue index: 20160708013130|76013207, 500 records retrieved.
# Search with continue index: 20160708141533|76021846, 500 records retrieved.
# Search with continue index: 20160709045621|76033109, 500 records retrieved.
# Search with continue index: 20160709191230|76043265, 500 records retrieved.
# Search with continue index: 20160710071537|76050604, 500 records retrieved.
# Search with continue index: 20160710190911|76058391, 500 records retrieved.
# Search with continue index: 20160711041528|76064981, 500 records retrieved.
# Search with continue index: 20160711111541|76069970, 500 records retrieved.
# Search with continue index: 20160711190732|76077563, 500 records retrieved.
# Search with continue index: 20160712060738|76085926, 500 records retrieved.
# Search with continue index: 20160712100857|76089403, 500 records retrieved.
# Search with continue index: 20160712175638|76095998, 500 records retrieved.
# Search with continue index: 20160712211535|76099301, 500 records retrieved.
# Search with continue index: 20160713071141|76106427, 500 records retrieved.
# Search with continue index: 20160713120737|76110554, 500 records retrieved.
# Search with continue index: 20160713190734|76117612, 500 records retrieved.
# Search with continue index: 20160713231536|76122018, 500 records retrieved.
# Search with continue index: 20160714095128|76129550, 500 records retrieved.
# Search with continue index: 20160714142853|76133821, 500 records retrieved.
# Search with continue index: 20160714231532|76142122, 500 records retrieved.
# Search with continue index: 20160715093128|76149671, 500 records retrieved.
# Search with continue index: 20160715133132|76153513, 500 records retrieved.
# Search with continue index: 20160715201547|76160100, 500 records retrieved.
# Search with continue index: 20160716023918|76165335, 500 records retrieved.
# Search with continue index: 20160716111531|76172359, 500 records retrieved.
# Search with continue index: 20160716180730|76178568, 500 records retrieved.
# Search with continue index: 20160717023027|76184606, 500 records retrieved.
# Search with continue index: 20160717092329|76189379, 500 records retrieved.
# Search with continue index: 20160717162612|76195166, 500 records retrieved.
# Search with continue index: 20160718001229|76201372, 500 records retrieved.
# Search with continue index: 20160718081536|76206958, 500 records retrieved.
# Search with continue index: 20160718170654|76214717, 500 records retrieved.
# Search with continue index: 20160718221534|76219640, 500 records retrieved.
# Search with continue index: 20160719051531|76224545, 500 records retrieved.
# Search with continue index: 20160719130206|76230881, 500 records retrieved.
# Search with continue index: 20160719210806|76237901, 500 records retrieved.
# Search with continue index: 20160720070733|76244170, 500 records retrieved.
# Search with continue index: 20160720114031|76247810, 500 records retrieved.
# Search with continue index: 20160720191528|76255308, 500 records retrieved.
# Search with continue index: 20160721033638|76262242, 500 records retrieved.
# Search with continue index: 20160721104604|76267515, 500 records retrieved.
# Search with continue index: 20160721191545|76275252, 500 records retrieved.
# Search with continue index: 20160722031536|76281323, 500 records retrieved.
# Search with continue index: 20160722110732|76286517, 500 records retrieved.
# Search with continue index: 20160722171539|76291624, 500 records retrieved.
# Search with continue index: 20160723020327|76297913, 500 records retrieved.
# Search with continue index: 20160723130741|76305294, 500 records retrieved.
# Search with continue index: 20160723192336|76310482, 500 records retrieved.
# Search with continue index: 20160724060730|76317060, 500 records retrieved.
# Search with continue index: 20160724161532|76327056, 500 records retrieved.
# Search with continue index: 20160725033736|76343695, 500 records retrieved.
# Search with continue index: 20160725120730|76349966, 500 records retrieved.
# Search with continue index: 20160725181535|76355543, 500 records retrieved.
# Search with continue index: 20160726025435|76363095, 500 records retrieved.
# Search with continue index: 20160726122326|76370837, 500 records retrieved.
# Search with continue index: 20160726213909|76378864, 500 records retrieved.
# Search with continue index: 20160727092326|76386225, 500 records retrieved.
# Search with continue index: 20160727191535|76394723, 500 records retrieved.
# Search with continue index: 20160728061533|76403950, 500 records retrieved.
# Search with continue index: 20160728172618|76414130, 500 records retrieved.
# Search with continue index: 20160729041228|76422932, 500 records retrieved.
# Search with continue index: 20160729131539|76429017, 500 records retrieved.
# Search with continue index: 20160729231124|76436651, 500 records retrieved.
# Search with continue index: 20160730081543|76442336, 500 records retrieved.
# Search with continue index: 20160730181530|76450321, 500 records retrieved.
# Search with continue index: 20160731042326|76456741, 500 records retrieved.
# Search with continue index: 20160731141532|76462972, 374 records retrieved.
# Retrieval complete for logs between 2016-07-01T00:00:00Z and 2016-08-01T00:00:00Z.
# 43374 records retrieved.
# 500 records retrieved.
# Search with continue index: 20160801100729|76477008, 500 records retrieved.
# Search with continue index: 20160801191529|76485524, 500 records retrieved.
# Search with continue index: 20160802041535|76492347, 500 records retrieved.
# Search with continue index: 20160802155519|76502571, 500 records retrieved.
# Search with continue index: 20160803021530|76510960, 500 records retrieved.
# Search with continue index: 20160803101545|76516194, 500 records retrieved.
# Search with continue index: 20160803190727|76524076, 500 records retrieved.
# Search with continue index: 20160803230737|76527677, 500 records retrieved.
# Search with continue index: 20160804074228|76533402, 500 records retrieved.
# Search with continue index: 20160804183232|76541904, 500 records retrieved.
# Search with continue index: 20160805062431|76550338, 500 records retrieved.
# Search with continue index: 20160805163128|76557734, 500 records retrieved.
# Search with continue index: 20160806021525|76572853, 500 records retrieved.
# Search with continue index: 20160806150740|76580743, 500 records retrieved.
# Search with continue index: 20160807034139|76589553, 500 records retrieved.
# Search with continue index: 20160807160623|76598242, 500 records retrieved.
# Search with continue index: 20160808020948|76605575, 500 records retrieved.
# Search with continue index: 20160808135631|76614579, 500 records retrieved.
# Search with continue index: 20160808210737|76621253, 500 records retrieved.
# Search with continue index: 20160809081529|76630225, 500 records retrieved.
# Search with continue index: 20160809171549|76638705, 500 records retrieved.
# Search with continue index: 20160809193519|76641256, 500 records retrieved.
# Search with continue index: 20160810080734|76651081, 500 records retrieved.
# Search with continue index: 20160810191535|76660494, 500 records retrieved.
# Search with continue index: 20160811044728|76667531, 500 records retrieved.
# Search with continue index: 20160811135208|76674426, 500 records retrieved.
# Search with continue index: 20160811211525|76681704, 500 records retrieved.
# Search with continue index: 20160812073517|76688626, 500 records retrieved.
# Search with continue index: 20160812171521|76696451, 500 records retrieved.
# Search with continue index: 20160813041527|76704281, 500 records retrieved.
# Search with continue index: 20160813121546|76709448, 500 records retrieved.
# ...
# Search with continue index: 20201028232127|112451129, 500 records retrieved.
# Search with continue index: 20201029080407|112457682, 500 records retrieved.
# Search with continue index: 20201029165320|112467074, 500 records retrieved.
# Search with continue index: 20201030000359|112475450, 500 records retrieved.
# Search with continue index: 20201030101743|112483025, 500 records retrieved.
# Search with continue index: 20201030184545|112492934, 500 records retrieved.
# Search with continue index: 20201031071312|112502583, 500 records retrieved.
# Search with continue index: 20201031164412|112510934, 302 records retrieved.
# Retrieval complete for logs between 2020-10-01T00:00:00Z and 2020-11-01T00:00:00Z.
# 42302 records retrieved.
# 500 records retrieved.
# Search with continue index: 20201101144416|112528004, 500 records retrieved.
# Search with continue index: 20201102003522|112539143, 500 records retrieved.
# Search with continue index: 20201102081927|112544737, 500 records retrieved.
# Search with continue index: 20201102142414|112549923, 500 records retrieved.
# Search with continue index: 20201102193653|112556480, 500 records retrieved.
# Search with continue index: 20201103015331|112562875, 500 records retrieved.
# Search with continue index: 20201103124902|112571216, 500 records retrieved.
# Search with continue index: 20201103200226|112579516, 500 records retrieved.
# Search with continue index: 20201104081619|112589021, 500 records retrieved.
# Search with continue index: 20201104180049|112597988, 500 records retrieved.
# Search with continue index: 20201105063557|112609435, 500 records retrieved.
# Search with continue index: 20201105183405|112620597, 500 records retrieved.
# Search with continue index: 20201106071810|112633162, 500 records retrieved.
# Search with continue index: 20201106181441|112643620, 500 records retrieved.
# Search with continue index: 20201107022413|112650510, 500 records retrieved.
# Search with continue index: 20201107182916|112663356, 500 records retrieved.
# Search with continue index: 20201108065329|112673855, 500 records retrieved.
# Search with continue index: 20201108210218|112687056, 500 records retrieved.
# Search with continue index: 20201109084701|112696769, 500 records retrieved.
# Search with continue index: 20201109181632|112707342, 500 records retrieved.
# Search with continue index: 20201110043526|112717871, 500 records retrieved.
# Search with continue index: 20201110161135|112728404, 500 records retrieved.
# Search with continue index: 20201111031051|112741048, 500 records retrieved.
# Search with continue index: 20201111162943|112752250, 500 records retrieved.
# Search with continue index: 20201112064220|112766451, 500 records retrieved.
# Search with continue index: 20201112182423|112777701, 500 records retrieved.
# Search with continue index: 20201113095409|112791590, 500 records retrieved.
# Search with continue index: 20201113181331|112800889, 500 records retrieved.
# Search with continue index: 20201114084314|112814941, 500 records retrieved.
# Search with continue index: 20201114231100|112828728, 500 records retrieved.
# Search with continue index: 20201115130131|112839118, 500 records retrieved.
# Search with continue index: 20201116010018|112851968, 500 records retrieved.
# Search with continue index: 20201116010258|112852503, 500 records retrieved.
# Search with continue index: 20201116021534|112854014, 500 records retrieved.
# Search with continue index: 20201116052910|112856691, 500 records retrieved.
# Search with continue index: 20201116092604|112859969, 500 records retrieved.
# Search with continue index: 20201116135017|112864129, 500 records retrieved.
# Search with continue index: 20201116172243|112869338, 500 records retrieved.
# Search with continue index: 20201116212028|112874552, 500 records retrieved.
# Search with continue index: 20201117022520|112880482, 500 records retrieved.
# Search with continue index: 20201117091850|112886136, 500 records retrieved.
# Search with continue index: 20201117135205|112890361, 500 records retrieved.
# Search with continue index: 20201117173742|112896197, 500 records retrieved.
# Search with continue index: 20201118011733|112905618, 500 records retrieved.
# Search with continue index: 20201118091632|112912267, 500 records retrieved.
# Search with continue index: 20201118153051|112918551, 500 records retrieved.
# Search with continue index: 20201118231304|112928174, 500 records retrieved.
# Search with continue index: 20201119071821|112935590, 500 records retrieved.
# Search with continue index: 20201119135324|112941370, 500 records retrieved.
# Search with continue index: 20201119202615|112949831, 500 records retrieved.
# Search with continue index: 20201120051602|112959018, 500 records retrieved.
# Search with continue index: 20201120121711|112965226, 500 records retrieved.
# Search with continue index: 20201120173549|112972267, 500 records retrieved.
# Search with continue index: 20201121011703|112980608, 500 records retrieved.
# Search with continue index: 20201121091641|112986131, 500 records retrieved.
# Search with continue index: 20201121135224|112991610, 500 records retrieved.
# Search with continue index: 20201121211522|113004341, 500 records retrieved.
# Search with continue index: 20201122062741|113011649, 500 records retrieved.
# Search with continue index: 20201122135054|113017855, 500 records retrieved.
# Search with continue index: 20201123000356|113028886, 500 records retrieved.
# Search with continue index: 20201123085756|113035479, 500 records retrieved.
# Search with continue index: 20201123135159|113040051, 500 records retrieved.
# Search with continue index: 20201123210322|113049612, 500 records retrieved.
# Search with continue index: 20201124051648|113056819, 500 records retrieved.
# Search with continue index: 20201124124238|113063270, 500 records retrieved.
# Search with continue index: 20201124182940|113070542, 500 records retrieved.
# Search with continue index: 20201125051714|113080440, 500 records retrieved.
# Search with continue index: 20201125095511|113084290, 500 records retrieved.
# Search with continue index: 20201125171129|113092076, 500 records retrieved.
# Search with continue index: 20201126001009|113100217, 500 records retrieved.
# Search with continue index: 20201126051327|113104179, 500 records retrieved.
# Search with continue index: 20201126130723|113110225, 500 records retrieved.
# Search with continue index: 20201126185229|113117994, 500 records retrieved.
# Search with continue index: 20201127051434|113126487, 500 records retrieved.
# Search with continue index: 20201127134837|113132960, 500 records retrieved.
# Search with continue index: 20201127185024|113139351, 500 records retrieved.
# Search with continue index: 20201128051612|113148309, 500 records retrieved.
# Search with continue index: 20201128111008|113152991, 500 records retrieved.
# Search with continue index: 20201128191546|113161691, 500 records retrieved.
# Search with continue index: 20201129020559|113168750, 500 records retrieved.
# Search with continue index: 20201129115729|113175885, 500 records retrieved.
# Search with continue index: 20201129174226|113182285, 500 records retrieved.
# Search with continue index: 20201130011934|113191551, 500 records retrieved.
# Search with continue index: 20201130091820|113197811, 500 records retrieved.
# Search with continue index: 20201130134950|113202273, 500 records retrieved.
# Search with continue index: 20201130183523|113209036, 299 records retrieved.
# Retrieval complete for logs between 2020-11-01T00:00:00Z and 2020-12-01T00:00:00Z.
# 43299 records retrieved.
# 500 records retrieved.
# Search with continue index: 20201201060139|113221306, 500 records retrieved.
# Search with continue index: 20201201120048|113226215, 500 records retrieved.
# Search with continue index: 20201201171814|113232912, 500 records retrieved.
# Search with continue index: 20201201211717|113239065, 500 records retrieved.
# Search with continue index: 20201202051756|113246727, 500 records retrieved.
# Search with continue index: 20201202134955|113254227, 500 records retrieved.
# Search with continue index: 20201202182745|113260860, 500 records retrieved.
# Search with continue index: 20201203011531|113268682, 500 records retrieved.
# Search with continue index: 20201203091607|113275287, 500 records retrieved.
# Search with continue index: 20201203135014|113279383, 500 records retrieved.
# Search with continue index: 20201203195647|113287548, 500 records retrieved.
# Search with continue index: 20201204051636|113296301, 500 records retrieved.
# Search with continue index: 20201204073518|113298628, 500 records retrieved.
# Search with continue index: 20201204135016|113304106, 500 records retrieved.
# Search with continue index: 20201204183832|113311017, 500 records retrieved.
# Search with continue index: 20201205013823|113318934, 500 records retrieved.
# Search with continue index: 20201205091717|113324238, 500 records retrieved.
# Search with continue index: 20201205161517|113331123, 500 records retrieved.
# Search with continue index: 20201205235914|113339259, 500 records retrieved.
# Search with continue index: 20201206065452|113344864, 500 records retrieved.
# Search with continue index: 20201206134637|113350546, 500 records retrieved.
# Search with continue index: 20201206180437|113357128, 500 records retrieved.
# Search with continue index: 20201206194232|113360027, 500 records retrieved.
# Search with continue index: 20201207011535|113367896, 500 records retrieved.
# Search with continue index: 20201207091620|113373959, 500 records retrieved.
# Search with continue index: 20201207141910|113378854, 500 records retrieved.
# Search with continue index: 20201207203347|113387219, 500 records retrieved.
# Search with continue index: 20201208051651|113395345, 500 records retrieved.
# Search with continue index: 20201208103337|113399270, 500 records retrieved.
# Search with continue index: 20201208171608|113407116, 500 records retrieved.
# Search with continue index: 20201209011548|113416809, 500 records retrieved.
# Search with continue index: 20201209091630|113423216, 500 records retrieved.
# Search with continue index: 20201209155808|113429589, 500 records retrieved.
# Search with continue index: 20201209211618|113436824, 500 records retrieved.
# Search with continue index: 20201210075957|113446534, 500 records retrieved.
# Search with continue index: 20201210144158|113452626, 500 records retrieved.
# Search with continue index: 20201210192627|113459019, 500 records retrieved.
# Search with continue index: 20201211041606|113467240, 500 records retrieved.
# Search with continue index: 20201211091537|113471059, 500 records retrieved.
# Search with continue index: 20201211143255|113475864, 500 records retrieved.
# Search with continue index: 20201211202835|113483253, 500 records retrieved.
# Search with continue index: 20201212051603|113492125, 500 records retrieved.
# Search with continue index: 20201212091908|113495209, 500 records retrieved.
# Search with continue index: 20201212161030|113502349, 500 records retrieved.
# Search with continue index: 20201212211615|113508189, 500 records retrieved.
# Search with continue index: 20201212221855|113509599, 500 records retrieved.
# Search with continue index: 20201213011556|113512624, 500 records retrieved.
# Search with continue index: 20201213120242|113521198, 500 records retrieved.
# Search with continue index: 20201213171523|113526644, 500 records retrieved.
# Search with continue index: 20201214011513|113536541, 500 records retrieved.
# Search with continue index: 20201214092236|113544071, 500 records retrieved.
# Search with continue index: 20201214144852|113550758, 500 records retrieved.
# Search with continue index: 20201214211619|113561089, 500 records retrieved.
# Search with continue index: 20201215051452|113568388, 500 records retrieved.
# Search with continue index: 20201215113757|113574215, 500 records retrieved.
# Search with continue index: 20201215171639|113581293, 500 records retrieved.
# Search with continue index: 20201215201340|113585448, 500 records retrieved.
# Search with continue index: 20201216011942|113591484, 500 records retrieved.
# Search with continue index: 20201216091533|113598720, 500 records retrieved.
# Search with continue index: 20201216144959|113604136, 500 records retrieved.
# Search with continue index: 20201216203449|113618811, 500 records retrieved.
# Search with continue index: 20201217051506|113630044, 500 records retrieved.
# Search with continue index: 20201217120345|113635938, 500 records retrieved.
# Search with continue index: 20201217182105|113651940, 500 records retrieved.
# Search with continue index: 20201218002534|113667223, 500 records retrieved.
# Search with continue index: 20201218064027|113672151, 500 records retrieved.
# Search with continue index: 20201218134827|113677755, 500 records retrieved.
# Search with continue index: 20201218192724|113689910, 500 records retrieved.
# Search with continue index: 20201219041318|113702982, 500 records retrieved.
# Search with continue index: 20201219111933|113708191, 500 records retrieved.
# Search with continue index: 20201219171542|113715849, 500 records retrieved.
# Search with continue index: 20201220012459|113737875, 500 records retrieved.
# Search with continue index: 20201220091716|113744331, 500 records retrieved.
# Search with continue index: 20201220171604|113752440, 500 records retrieved.
# Search with continue index: 20201221051654|113764428, 500 records retrieved.
# Search with continue index: 20201221134820|113771160, 500 records retrieved.
# Search with continue index: 20201221195353|113778332, 500 records retrieved.
# Search with continue index: 20201222051446|113789145, 500 records retrieved.
# Search with continue index: 20201222134811|113796259, 500 records retrieved.
# Search with continue index: 20201222211606|113805000, 500 records retrieved.
# Search with continue index: 20201223063726|113813047, 500 records retrieved.
# Search with continue index: 20201223134658|113819998, 500 records retrieved.
# Search with continue index: 20201223190235|113826418, 500 records retrieved.
# Search with continue index: 20201224021618|113833396, 500 records retrieved.
# Search with continue index: 20201224091529|113839173, 500 records retrieved.
# Search with continue index: 20201224171530|113846786, 500 records retrieved.
# Search with continue index: 20201224233443|113852388, 500 records retrieved.
# Search with continue index: 20201225051651|113856678, 500 records retrieved.
# Search with continue index: 20201225134919|113862618, 500 records retrieved.
# Search with continue index: 20201225222221|113869912, 500 records retrieved.
# Search with continue index: 20201226091623|113877100, 500 records retrieved.
# Search with continue index: 20201226152125|113882456, 500 records retrieved.
# Search with continue index: 20201226214416|113889577, 500 records retrieved.
# Search with continue index: 20201227080533|113898235, 500 records retrieved.
# Search with continue index: 20201227134759|113902921, 500 records retrieved.
# Search with continue index: 20201227211451|113912200, 500 records retrieved.
# Search with continue index: 20201228051712|113919631, 500 records retrieved.
# Search with continue index: 20201228132109|113926480, 500 records retrieved.
# Search with continue index: 20201228193939|113934788, 500 records retrieved.
# Search with continue index: 20201229032503|113943437, 500 records retrieved.
# Search with continue index: 20201229093103|113949194, 500 records retrieved.
# Search with continue index: 20201229171600|113958227, 500 records retrieved.
# Search with continue index: 20201230014734|113967611, 500 records retrieved.
# Search with continue index: 20201230100300|113973974, 500 records retrieved.
# Search with continue index: 20201230171644|113981886, 500 records retrieved.
# Search with continue index: 20201231041009|113995280, 500 records retrieved.
# Search with continue index: 20201231115806|114001682, 500 records retrieved.
# Search with continue index: 20201231171536|114007633, 373 records retrieved.
# Retrieval complete for logs between 2020-12-01T00:00:00Z and 2021-01-01T00:00:00Z.
# 54373 records retrieved.
