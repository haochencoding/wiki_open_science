# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook explains how to run the spider program to fetch block logs from Wikipedia API.

# %%
import requests
import pandas as pd

# %%
# append system path to import spider program
import sys
sys.path.append('../')
from utils.spiders import retrieve_block_logs_month # fetch data for a specific month in a given year
from utils.spiders import retrieve_block_logs_year # fetch data for a given year

# %% [markdown]
# # Code examples

# %% [markdown]
# ## Retrieve data for 1 month

# %% [markdown]
# To retrieve block logs for a specific month, please use the retrieve_block_logs_month function. It automatically retrive the logs and write them into a local csv file (format: year-month.csv).
#
# It requires 4 parameters:
# - year (int):
#     - The year for which block logs should be retrieved.
# - month (int):
#     - The month for which block logs should be retrieved.
# - folder_path (str):
#     - The folder path where the CSV file will be saved.
# - compress (bool):
#     - Specify if compress the CSV file into a gz file.
#
# Note:
# - If you encounter issues at running the function, please check if a file already exists on your local disk. This function automatically stop to prevent from overwritting local file.

# %%
# Set folder path to store fetched data
folder_path = '../data/block_logs/'

# %%
retrieve_block_logs_month(year=2006, month=2, folder_path=folder_path, compress=True)
# Out:
# ../data/block_logs/2006-02.csv already exists. Cannot overwrite.
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 retrieve_block_logs_month(year=2006, month=2, folder_path=folder_path, compress=True)
#
# File ~/Documents/France/Projects/wikipedia/wikipedia_scrapping/notebooks/../utils/spiders.py:121, in retrieve_block_logs_month(year, month, folder_path, compress)
#     119 if os.path.exists(file_path):
#     120     print(f"{file_path} already exists. Cannot overwrite.")
# --> 121     raise FileExistsError(f'Pls check if a {file_path} already exists on local disk.')
#     123 while True:
#     124     # print out continue index
#     125     if continue_index is not None:
#
# FileExistsError: Pls check if a ../data/block_logs/2006-02.csv already exists on local disk.

# %% [markdown]
# ## Retrieve data for 1 year

# %% [markdown]
# To retrieve block logs for a specific year, please use the retrieve_block_logs_month function. It automatically performs a loop of the month retrive function to download and store logs for a given year. The data will be stored in 12 local csv files (format: year-month.csv), each for 1 month.
#
# It requires 4 parameters:
# - year (int):
#     - The year for which block logs should be retrieved.
# - folder_path (str):
#     - The folder path where the CSV file will be saved.
# - compress (bool):
#     - Specify if compress the CSV file into a gz file.
#
# Note:
# - If you encounter issues at running the function, please check if a file already exists on your local disk. This function automatically stop to prevent from overwritting local file.

# %%
for i in range(2009, 2016, 1):
    retrieve_block_logs_year(year=i, folder_path=folder_path, compress=True)
# Out:
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015

# %%
retrieve_block_logs_year(year=2009, folder_path=folder_path, compress=True)
# Out:
# 500 records retrieved.
# Search with continue index: 20080101231752|12850350, 500 records retrieved.
# Search with continue index: 20080103010950|12870209, 500 records retrieved.
# Search with continue index: 20080103220145|12884564, 500 records retrieved.
# Search with continue index: 20080104193125|12899160, 500 records retrieved.
# Search with continue index: 20080105065423|12907743, 500 records retrieved.
# Search with continue index: 20080106063921|12926262, 500 records retrieved.
# Search with continue index: 20080107135713|12945545, 500 records retrieved.
# Search with continue index: 20080108003732|12953869, 500 records retrieved.
# Search with continue index: 20080108181834|12964772, 500 records retrieved.
# Search with continue index: 20080109133913|12988631, 500 records retrieved.
# Search with continue index: 20080110001752|12996772, 500 records retrieved.
# Search with continue index: 20080110173502|13007682, 500 records retrieved.
# Search with continue index: 20080111075901|13022517, 500 records retrieved.
# Search with continue index: 20080111212605|13032132, 500 records retrieved.
# Search with continue index: 20080112215733|13068355, 500 records retrieved.
# Search with continue index: 20080113215141|13084794, 500 records retrieved.
# Search with continue index: 20080114165753|13097971, 500 records retrieved.
# Search with continue index: 20080115042215|13109211, 500 records retrieved.
# Search with continue index: 20080115214051|13122061, 500 records retrieved.
# Search with continue index: 20080116161001|13134541, 500 records retrieved.
# Search with continue index: 20080117025116|13145736, 500 records retrieved.
# Search with continue index: 20080117194048|13159112, 500 records retrieved.
# Search with continue index: 20080118154615|13174751, 500 records retrieved.
# Search with continue index: 20080119132513|13189753, 500 records retrieved.
# Search with continue index: 20080120171402|13210441, 500 records retrieved.
# Search with continue index: 20080121034112|13220444, 500 records retrieved.
# Search with continue index: 20080121221104|13234738, 500 records retrieved.
# Search with continue index: 20080122174755|13249496, 500 records retrieved.
# Search with continue index: 20080123073623|13263855, 500 records retrieved.
# Search with continue index: 20080123204405|13272794, 500 records retrieved.
# Search with continue index: 20080124150600|13285875, 500 records retrieved.
# Search with continue index: 20080125032852|13296755, 500 records retrieved.
# Search with continue index: 20080125200046|13307201, 500 records retrieved.
# Search with continue index: 20080127000042|13326742, 500 records retrieved.
# Search with continue index: 20080128000159|13342154, 500 records retrieved.
# Search with continue index: 20080128192844|13354919, 500 records retrieved.
# Search with continue index: 20080129151426|13370402, 500 records retrieved.
# Search with continue index: 20080130030336|13383095, 500 records retrieved.
# Search with continue index: 20080130181518|13392212, 500 records retrieved.
# Search with continue index: 20080131102402|13404583, 500 records retrieved.
# Search with continue index: 20080131185812|13411107, 300 records retrieved.
# Retrieval complete for logs between 2008-01-01T00:00:00Z and 2008-02-01T00:00:00Z.
# 20800 records retrieved.
# 500 records retrieved.
# Search with continue index: 20080201174413|13426629, 500 records retrieved.
# Search with continue index: 20080202111313|13438423, 500 records retrieved.
# Search with continue index: 20080203142159|13454311, 500 records retrieved.
# Search with continue index: 20080204150457|13472198, 500 records retrieved.
# Search with continue index: 20080205011106|13481742, 500 records retrieved.
# Search with continue index: 20080205193608|13494745, 500 records retrieved.
# Search with continue index: 20080206125338|13507403, 500 records retrieved.
# Search with continue index: 20080206211946|13514729, 500 records retrieved.
# Search with continue index: 20080207155533|13527281, 500 records retrieved.
# Search with continue index: 20080208024108|13536908, 500 records retrieved.
# Search with continue index: 20080208175001|13550348, 500 records retrieved.
# Search with continue index: 20080209055409|13559313, 500 records retrieved.
# Search with continue index: 20080210104036|13577863, 500 records retrieved.
# Search with continue index: 20080211110950|13596154, 500 records retrieved.
# Search with continue index: 20080211214428|13605003, 500 records retrieved.
# Search with continue index: 20080212152354|13617304, 500 records retrieved.
# Search with continue index: 20080213013049|13626261, 500 records retrieved.
# Search with continue index: 20080213164222|13637017, 500 records retrieved.
# Search with continue index: 20080214013108|13645174, 500 records retrieved.
# Search with continue index: 20080214173015|13658297, 500 records retrieved.
# Search with continue index: 20080215024144|13667104, 500 records retrieved.
# Search with continue index: 20080215174813|13678218, 500 records retrieved.
# Search with continue index: 20080216152502|13694881, 500 records retrieved.
# Search with continue index: 20080217063847|13707858, 500 records retrieved.
# Search with continue index: 20080217192605|13741338, 500 records retrieved.
# Search with continue index: 20080218081342|13762808, 500 records retrieved.
# Search with continue index: 20080218201642|13774019, 500 records retrieved.
# Search with continue index: 20080219153717|13791422, 500 records retrieved.
# Search with continue index: 20080220012040|13801663, 500 records retrieved.
# Search with continue index: 20080220184300|13814200, 500 records retrieved.
# Search with continue index: 20080221110253|13826201, 500 records retrieved.
# Search with continue index: 20080221204422|13836244, 500 records retrieved.
# Search with continue index: 20080222140115|13848688, 500 records retrieved.
# Search with continue index: 20080223041914|13862577, 500 records retrieved.
# Search with continue index: 20080224151114|13887603, 500 records retrieved.
# Search with continue index: 20080225044118|13900981, 500 records retrieved.
# Search with continue index: 20080225200332|13911572, 500 records retrieved.
# Search with continue index: 20080226143837|13925068, 500 records retrieved.
# Search with continue index: 20080226223801|13934091, 500 records retrieved.
# Search with continue index: 20080227152220|13950104, 500 records retrieved.
# Search with continue index: 20080227232559|13959199, 500 records retrieved.
# Search with continue index: 20080228164633|13971270, 500 records retrieved.
# Search with continue index: 20080229025509|13981594, 500 records retrieved.
# Search with continue index: 20080229181105|13999802, 250 records retrieved.
# Retrieval complete for logs between 2008-02-01T00:00:00Z and 2008-03-01T00:00:00Z.
# 22250 records retrieved.
# 500 records retrieved.
# Search with continue index: 20080301233044|14021427, 500 records retrieved.
# Search with continue index: 20080302220448|14037101, 500 records retrieved.
# Search with continue index: 20080303161632|14052680, 500 records retrieved.
# Search with continue index: 20080304033718|14069436, 500 records retrieved.
# Search with continue index: 20080304194313|14080230, 500 records retrieved.
# Search with continue index: 20080305124031|14093796, 500 records retrieved.
# Search with continue index: 20080305231226|14102859, 500 records retrieved.
# Search with continue index: 20080306155748|14113698, 500 records retrieved.
# Search with continue index: 20080307035202|14123298, 500 records retrieved.
# Search with continue index: 20080307174039|14131322, 500 records retrieved.
# Search with continue index: 20080308154938|14145951, 500 records retrieved.
# Search with continue index: 20080309174250|14164124, 500 records retrieved.
# Search with continue index: 20080310142917|14177652, 500 records retrieved.
# Search with continue index: 20080311004342|14186747, 500 records retrieved.
# Search with continue index: 20080311175150|14197965, 500 records retrieved.
# Search with continue index: 20080312043159|14208520, 500 records retrieved.
# Search with continue index: 20080312175157|14223925, 500 records retrieved.
# Search with continue index: 20080313065021|14234659, 500 records retrieved.
# Search with continue index: 20080313203046|14243843, 500 records retrieved.
# Search with continue index: 20080314141041|14254703, 500 records retrieved.
# Search with continue index: 20080315024508|14263517, 500 records retrieved.
# Search with continue index: 20080316025855|14277769, 500 records retrieved.
# Search with continue index: 20080317045326|14293331, 500 records retrieved.
# Search with continue index: 20080317184101|14302134, 500 records retrieved.
# Search with continue index: 20080318122232|14313089, 500 records retrieved.
# Search with continue index: 20080318223623|14321399, 500 records retrieved.
# Search with continue index: 20080319160921|14333359, 500 records retrieved.
# Search with continue index: 20080320002448|14340597, 500 records retrieved.
# Search with continue index: 20080320191245|14351260, 500 records retrieved.
# Search with continue index: 20080321180216|14366785, 500 records retrieved.
# Search with continue index: 20080322210418|14385613, 500 records retrieved.
# Search with continue index: 20080324033148|14405928, 500 records retrieved.
# Search with continue index: 20080325024313|14422829, 500 records retrieved.
# Search with continue index: 20080325192139|14433350, 500 records retrieved.
# Search with continue index: 20080326140103|14445386, 500 records retrieved.
# Search with continue index: 20080327023644|14456586, 500 records retrieved.
# Search with continue index: 20080327171412|14465825, 500 records retrieved.
# Search with continue index: 20080328123154|14479744, 500 records retrieved.
# Search with continue index: 20080329022848|14490837, 500 records retrieved.
# Search with continue index: 20080330021137|14505977, 500 records retrieved.
# Search with continue index: 20080331011053|14520944, 500 records retrieved.
# Search with continue index: 20080331185648|14533533, 248 records retrieved.
# Retrieval complete for logs between 2008-03-01T00:00:00Z and 2008-04-01T00:00:00Z.
# 21248 records retrieved.
# 500 records retrieved.
# Search with continue index: 20080401175151|14551632, 500 records retrieved.
# Search with continue index: 20080402071512|14566158, 500 records retrieved.
# Search with continue index: 20080402212205|14576494, 500 records retrieved.
# Search with continue index: 20080403160428|14588748, 500 records retrieved.
# Search with continue index: 20080404030144|14598713, 500 records retrieved.
# Search with continue index: 20080404194105|14610551, 500 records retrieved.
# Search with continue index: 20080405200143|14626605, 500 records retrieved.
# Search with continue index: 20080406193430|14641077, 500 records retrieved.
# Search with continue index: 20080407160823|14668137, 500 records retrieved.
# Search with continue index: 20080408075010|14680326, 500 records retrieved.
# Search with continue index: 20080408223318|14691417, 500 records retrieved.
# Search with continue index: 20080409143935|14701905, 500 records retrieved.
# Search with continue index: 20080410005816|14711781, 500 records retrieved.
# Search with continue index: 20080410175934|14727512, 500 records retrieved.
# Search with continue index: 20080411131903|14740718, 500 records retrieved.
# Search with continue index: 20080412074204|14753348, 500 records retrieved.
# Search with continue index: 20080413150515|14782617, 500 records retrieved.
# Search with continue index: 20080414133322|14796975, 500 records retrieved.
# Search with continue index: 20080414222813|14805093, 500 records retrieved.
# Search with continue index: 20080415160203|14820644, 500 records retrieved.
# Search with continue index: 20080416054220|14831329, 500 records retrieved.
# Search with continue index: 20080416200732|14840659, 500 records retrieved.
# Search with continue index: 20080417133426|14850729, 500 records retrieved.
# Search with continue index: 20080418002442|14858650, 500 records retrieved.
# Search with continue index: 20080418183557|14872623, 500 records retrieved.
# Search with continue index: 20080419212450|14889203, 500 records retrieved.
# Search with continue index: 20080420131130|14897294, 500 records retrieved.
# Search with continue index: 20080420145720|14898720, 500 records retrieved.
# Search with continue index: 20080420170754|14900672, 500 records retrieved.
# Search with continue index: 20080420204526|14903967, 500 records retrieved.
# Search with continue index: 20080421044434|14910106, 500 records retrieved.
# Search with continue index: 20080421104941|14913275, 500 records retrieved.
# Search with continue index: 20080421192057|14919391, 500 records retrieved.
# Search with continue index: 20080422141837|14931004, 500 records retrieved.
# Search with continue index: 20080423004058|14939185, 500 records retrieved.
# Search with continue index: 20080423193911|14950971, 500 records retrieved.
# Search with continue index: 20080424143503|14971508, 500 records retrieved.
# Search with continue index: 20080425015259|14980591, 500 records retrieved.
# Search with continue index: 20080425202945|14992239, 500 records retrieved.
# Search with continue index: 20080427024230|15010111, 500 records retrieved.
# Search with continue index: 20080428060702|15025580, 500 records retrieved.
# Search with continue index: 20080428201628|15035354, 500 records retrieved.
# Search with continue index: 20080429133112|15046132, 500 records retrieved.
# Search with continue index: 20080429213959|15052896, 500 records retrieved.
# Search with continue index: 20080430153146|15064128, 393 records retrieved.
# Retrieval complete for logs between 2008-04-01T00:00:00Z and 2008-05-01T00:00:00Z.
# 22893 records retrieved.
# 500 records retrieved.
# Search with continue index: 20080501182927|15082628, 500 records retrieved.
# Search with continue index: 20080502063108|15091521, 500 records retrieved.
# Search with continue index: 20080502185721|15099010, 500 records retrieved.
# Search with continue index: 20080503172420|15113746, 500 records retrieved.
# Search with continue index: 20080504085245|15123533, 500 records retrieved.
# Search with continue index: 20080505103001|15137912, 500 records retrieved.
# Search with continue index: 20080505232400|15148390, 500 records retrieved.
# Search with continue index: 20080506163256|15159059, 500 records retrieved.
# Search with continue index: 20080507033824|15168685, 500 records retrieved.
# Search with continue index: 20080507191338|15178497, 500 records retrieved.
# Search with continue index: 20080508151537|15191981, 500 records retrieved.
# Search with continue index: 20080509032712|15201505, 500 records retrieved.
# Search with continue index: 20080509210146|15212388, 500 records retrieved.
# Search with continue index: 20080510194753|15228931, 500 records retrieved.
# Search with continue index: 20080511235339|15245365, 500 records retrieved.
# Search with continue index: 20080512172032|15256568, 500 records retrieved.
# Search with continue index: 20080513083144|15267284, 500 records retrieved.
# Search with continue index: 20080513211811|15277582, 500 records retrieved.
# Search with continue index: 20080514145921|15288550, 500 records retrieved.
# Search with continue index: 20080515022043|15298017, 500 records retrieved.
# Search with continue index: 20080515172122|15308545, 500 records retrieved.
# Search with continue index: 20080516034114|15316764, 500 records retrieved.
# Search with continue index: 20080516190822|15326141, 500 records retrieved.
# Search with continue index: 20080518000100|15343004, 500 records retrieved.
# Search with continue index: 20080519020547|15359230, 500 records retrieved.
# Search with continue index: 20080519201244|15369777, 500 records retrieved.
# Search with continue index: 20080520145634|15381429, 500 records retrieved.
# Search with continue index: 20080521001445|15389196, 500 records retrieved.
# Search with continue index: 20080521164137|15398995, 500 records retrieved.
# Search with continue index: 20080522124432|15410716, 500 records retrieved.
# Search with continue index: 20080522230323|15418965, 500 records retrieved.
# Search with continue index: 20080523182156|15430102, 500 records retrieved.
# Search with continue index: 20080524052850|15437610, 500 records retrieved.
# Search with continue index: 20080524163735|15442916, 500 records retrieved.
# Search with continue index: 20080525021635|15449012, 500 records retrieved.
# Search with continue index: 20080525235526|15460842, 500 records retrieved.
# Search with continue index: 20080526151110|15470197, 500 records retrieved.
# Search with continue index: 20080527165153|15490113, 500 records retrieved.
# Search with continue index: 20080528045620|15500709, 500 records retrieved.
# Search with continue index: 20080528210703|15511058, 500 records retrieved.
# Search with continue index: 20080529153024|15522858, 500 records retrieved.
# Search with continue index: 20080530094330|15535097, 500 records retrieved.
# Search with continue index: 20080531043757|15548256, 297 records retrieved.
# Retrieval complete for logs between 2008-05-01T00:00:00Z and 2008-06-01T00:00:00Z.
# 21797 records retrieved.
# 500 records retrieved.
# Search with continue index: 20080602023130|15581296, 500 records retrieved.
# Search with continue index: 20080602185553|15591008, 500 records retrieved.
# Search with continue index: 20080603121617|15601756, 500 records retrieved.
# Search with continue index: 20080604050153|15615805, 500 records retrieved.
# Search with continue index: 20080604235549|15629316, 500 records retrieved.
# Search with continue index: 20080605184952|15641326, 500 records retrieved.
# Search with continue index: 20080606125505|15653090, 500 records retrieved.
# Search with continue index: 20080607110119|15667678, 500 records retrieved.
# Search with continue index: 20080608120520|15680745, 500 records retrieved.
# Search with continue index: 20080609125656|15698585, 500 records retrieved.
# Search with continue index: 20080610031906|15709027, 500 records retrieved.
# Search with continue index: 20080610204645|15720321, 500 records retrieved.
# Search with continue index: 20080611172057|15734819, 500 records retrieved.
# Search with continue index: 20080612084035|15745785, 500 records retrieved.
# Search with continue index: 20080613014212|15757204, 500 records retrieved.
# Search with continue index: 20080614011203|15770823, 500 records retrieved.
# Search with continue index: 20080615084647|15788091, 500 records retrieved.
# Search with continue index: 20080616162252|15806582, 500 records retrieved.
# Search with continue index: 20080617160522|15822934, 500 records retrieved.
# Search with continue index: 20080618194242|15840546, 500 records retrieved.
# Search with continue index: 20080619182558|15853628, 500 records retrieved.
# Search with continue index: 20080621010436|15872763, 500 records retrieved.
# Search with continue index: 20080622130505|15890035, 500 records retrieved.
# Search with continue index: 20080623212549|15908454, 500 records retrieved.
# Search with continue index: 20080624203319|15921957, 500 records retrieved.
# Search with continue index: 20080625215630|15936448, 500 records retrieved.
# Search with continue index: 20080627043905|15953912, 500 records retrieved.
# Search with continue index: 20080628161947|15970214, 500 records retrieved.
# Search with continue index: 20080629221316|15985210, 448 records retrieved.
# Retrieval complete for logs between 2008-06-01T00:00:00Z and 2008-07-01T00:00:00Z.
# 14948 records retrieved.
# 500 records retrieved.
# Search with continue index: 20080702050933|16015100, 500 records retrieved.
# Search with continue index: 20080703181504|16034530, 500 records retrieved.
# Search with continue index: 20080705064931|16053321, 500 records retrieved.
# Search with continue index: 20080706000104|16061383, 500 records retrieved.
# Search with continue index: 20080706003138|16062090, 500 records retrieved.
# Search with continue index: 20080706005508|16062756, 500 records retrieved.
# Search with continue index: 20080706011730|16063399, 500 records retrieved.
# Search with continue index: 20080706015659|16064660, 500 records retrieved.
# Search with continue index: 20080706021518|16065387, 500 records retrieved.
# Search with continue index: 20080706022951|16066030, 500 records retrieved.
# Search with continue index: 20080706024404|16066663, 500 records retrieved.
# Search with continue index: 20080706031246|16067422, 500 records retrieved.
# Search with continue index: 20080706035046|16068166, 500 records retrieved.
# Search with continue index: 20080706043206|16069181, 500 records retrieved.
# Search with continue index: 20080706224159|16083360, 500 records retrieved.
# Search with continue index: 20080707205012|16104047, 500 records retrieved.
# Search with continue index: 20080707213450|16105437, 500 records retrieved.
# Search with continue index: 20080707225148|16107409, 500 records retrieved.
# Search with continue index: 20080708231700|16134971, 500 records retrieved.
# Search with continue index: 20080710013744|16163237, 500 records retrieved.
# Search with continue index: 20080711081257|16198094, 500 records retrieved.
# Search with continue index: 20080712164005|16229146, 500 records retrieved.
# Search with continue index: 20080714033348|16247865, 500 records retrieved.
# Search with continue index: 20080715043944|16262989, 500 records retrieved.
# Search with continue index: 20080716061802|16277482, 500 records retrieved.
# Search with continue index: 20080717154317|16295110, 500 records retrieved.
# Search with continue index: 20080718235057|16312831, 500 records retrieved.
# Search with continue index: 20080720165032|16339464, 500 records retrieved.
# Search with continue index: 20080721215515|16356071, 500 records retrieved.
# Search with continue index: 20080723002044|16374058, 500 records retrieved.
# Search with continue index: 20080723054621|16377573, 500 records retrieved.
# Search with continue index: 20080723144750|16382548, 500 records retrieved.
# Search with continue index: 20080724035942|16390898, 500 records retrieved.
# Search with continue index: 20080724042117|16391526, 500 records retrieved.
# Search with continue index: 20080724222606|16402252, 500 records retrieved.
# Search with continue index: 20080725221105|16415759, 500 records retrieved.
# Search with continue index: 20080727074850|16432520, 500 records retrieved.
# Search with continue index: 20080728122244|16446148, 500 records retrieved.
# Search with continue index: 20080728202658|16452788, 500 records retrieved.
# Search with continue index: 20080728203442|16453400, 500 records retrieved.
# Search with continue index: 20080729080601|16460115, 500 records retrieved.
# Search with continue index: 20080730064233|16473416, 500 records retrieved.
# Search with continue index: 20080731041901|16485050, 456 records retrieved.
# Retrieval complete for logs between 2008-07-01T00:00:00Z and 2008-08-01T00:00:00Z.
# 21956 records retrieved.
# 500 records retrieved.
# Search with continue index: 20080802015720|16510304, 500 records retrieved.
# Search with continue index: 20080803165919|16534266, 500 records retrieved.
# Search with continue index: 20080804205911|16550057, 500 records retrieved.
# Search with continue index: 20080805185716|16562232, 500 records retrieved.
# Search with continue index: 20080806204926|16577264, 500 records retrieved.
# Search with continue index: 20080808042843|16593569, 500 records retrieved.
# Search with continue index: 20080809124813|16608316, 500 records retrieved.
# Search with continue index: 20080810170828|16622089, 500 records retrieved.
# Search with continue index: 20080811131540|16633273, 500 records retrieved.
# Search with continue index: 20080812053053|16644288, 500 records retrieved.
# Search with continue index: 20080813063838|16659415, 500 records retrieved.
# Search with continue index: 20080814113950|16675670, 500 records retrieved.
# Search with continue index: 20080815003143|16683858, 500 records retrieved.
# Search with continue index: 20080815223012|16698365, 500 records retrieved.
# Search with continue index: 20080816233556|16710874, 500 records retrieved.
# Search with continue index: 20080818021904|16725948, 500 records retrieved.
# Search with continue index: 20080819022935|16739577, 500 records retrieved.
# Search with continue index: 20080820013932|16752721, 500 records retrieved.
# Search with continue index: 20080821011437|16765263, 500 records retrieved.
# Search with continue index: 20080822034727|16779481, 500 records retrieved.
# Search with continue index: 20080823045358|16793221, 500 records retrieved.
# Search with continue index: 20080824155044|16810493, 500 records retrieved.
# Search with continue index: 20080825182344|16827019, 500 records retrieved.
# Search with continue index: 20080826153120|16840097, 500 records retrieved.
# Search with continue index: 20080827115213|16853460, 500 records retrieved.
# Search with continue index: 20080828042705|16863953, 500 records retrieved.
# Search with continue index: 20080829064215|16878719, 500 records retrieved.
# Search with continue index: 20080830030222|16890415, 500 records retrieved.
# Search with continue index: 20080831233307|16913347, 18 records retrieved.
# Retrieval complete for logs between 2008-08-01T00:00:00Z and 2008-09-01T00:00:00Z.
# 14518 records retrieved.
# 500 records retrieved.
# Search with continue index: 20080901222354|16928444, 500 records retrieved.
# Search with continue index: 20080902211455|16941654, 500 records retrieved.
# Search with continue index: 20080903201314|16956254, 500 records retrieved.
# Search with continue index: 20080904152532|16968573, 500 records retrieved.
# Search with continue index: 20080905075622|16979870, 500 records retrieved.
# Search with continue index: 20080906001601|16990306, 500 records retrieved.
# Search with continue index: 20080906173812|17001255, 500 records retrieved.
# Search with continue index: 20080907204829|17017035, 500 records retrieved.
# Search with continue index: 20080908103639|17024576, 500 records retrieved.
# Search with continue index: 20080908230046|17032948, 500 records retrieved.
# Search with continue index: 20080909173113|17044687, 500 records retrieved.
# Search with continue index: 20080910011239|17051257, 500 records retrieved.
# Search with continue index: 20080910185014|17061331, 500 records retrieved.
# Search with continue index: 20080911154013|17073862, 500 records retrieved.
# Search with continue index: 20080912081247|17084316, 500 records retrieved.
# Search with continue index: 20080913001253|17094670, 500 records retrieved.
# Search with continue index: 20080914000141|17106553, 500 records retrieved.
# Search with continue index: 20080914214313|17120021, 500 records retrieved.
# Search with continue index: 20080915150841|17130349, 500 records retrieved.
# Search with continue index: 20080916031149|17139345, 500 records retrieved.
# Search with continue index: 20080916174343|17150584, 500 records retrieved.
# Search with continue index: 20080917123623|17162365, 500 records retrieved.
# Search with continue index: 20080918013710|17172534, 500 records retrieved.
# Search with continue index: 20080918190545|17182945, 500 records retrieved.
# Search with continue index: 20080919144011|17196877, 500 records retrieved.
# Search with continue index: 20080920073319|17207950, 500 records retrieved.
# Search with continue index: 20080921210045|17230755, 500 records retrieved.
# Search with continue index: 20080922201645|17246239, 500 records retrieved.
# Search with continue index: 20080923143831|17259548, 500 records retrieved.
# Search with continue index: 20080924052427|17272792, 500 records retrieved.
# Search with continue index: 20080925023716|17287342, 500 records retrieved.
# Search with continue index: 20080925191524|17299143, 500 records retrieved.
# Search with continue index: 20080926160205|17312879, 500 records retrieved.
# Search with continue index: 20080927193920|17330390, 500 records retrieved.
# Search with continue index: 20080928200742|17347559, 500 records retrieved.
# Search with continue index: 20080929163401|17361845, 500 records retrieved.
# Search with continue index: 20080930063526|17374731, 500 records retrieved.
# Search with continue index: 20080930210850|17385209, 89 records retrieved.
# Retrieval complete for logs between 2008-09-01T00:00:00Z and 2008-10-01T00:00:00Z.
# 19089 records retrieved.
# 500 records retrieved.
# Search with continue index: 20081001190853|17404237, 500 records retrieved.
# Search with continue index: 20081002143533|17420443, 500 records retrieved.
# Search with continue index: 20081003044148|17435519, 500 records retrieved.
# Search with continue index: 20081003213833|17448852, 500 records retrieved.
# Search with continue index: 20081004215932|17467866, 500 records retrieved.
# Search with continue index: 20081006000922|17487282, 500 records retrieved.
# Search with continue index: 20081006191436|17500400, 500 records retrieved.
# Search with continue index: 20081007141828|17514972, 500 records retrieved.
# Search with continue index: 20081008031040|17529650, 500 records retrieved.
# Search with continue index: 20081008182218|17544653, 500 records retrieved.
# Search with continue index: 20081009070750|17558190, 500 records retrieved.
# Search with continue index: 20081009223348|17582793, 500 records retrieved.
# Search with continue index: 20081010172000|17602214, 500 records retrieved.
# Search with continue index: 20081011064317|17612667, 500 records retrieved.
# Search with continue index: 20081012102302|17630313, 500 records retrieved.
# Search with continue index: 20081013135212|17648494, 500 records retrieved.
# Search with continue index: 20081014040032|17661282, 500 records retrieved.
# Search with continue index: 20081014222042|17675516, 500 records retrieved.
# Search with continue index: 20081015180028|17689841, 500 records retrieved.
# Search with continue index: 20081016130353|17704971, 500 records retrieved.
# Search with continue index: 20081017032625|17720551, 500 records retrieved.
# Search with continue index: 20081017165414|17729886, 500 records retrieved.
# Search with continue index: 20081018175127|17748969, 500 records retrieved.
# Search with continue index: 20081019195601|17765935, 500 records retrieved.
# Search with continue index: 20081020154601|17781252, 500 records retrieved.
# Search with continue index: 20081021052652|17792970, 500 records retrieved.
# Search with continue index: 20081021195301|17803414, 500 records retrieved.
# Search with continue index: 20081022132051|17815415, 500 records retrieved.
# Search with continue index: 20081022222358|17823810, 500 records retrieved.
# Search with continue index: 20081023165801|17842217, 500 records retrieved.
# Search with continue index: 20081024061855|17855882, 500 records retrieved.
# Search with continue index: 20081025001444|17870539, 500 records retrieved.
# Search with continue index: 20081026060245|17891203, 500 records retrieved.
# Search with continue index: 20081027005107|17905262, 500 records retrieved.
# Search with continue index: 20081027192712|17918901, 500 records retrieved.
# Search with continue index: 20081028023211|17926377, 500 records retrieved.
# Search with continue index: 20081028163941|17935633, 500 records retrieved.
# Search with continue index: 20081029041824|17947187, 500 records retrieved.
# Search with continue index: 20081029230102|17960535, 500 records retrieved.
# Search with continue index: 20081030160437|17973147, 500 records retrieved.
# Search with continue index: 20081031081014|17984898, 476 records retrieved.
# Retrieval complete for logs between 2008-10-01T00:00:00Z and 2008-11-01T00:00:00Z.
# 20976 records retrieved.
# 500 records retrieved.
# Search with continue index: 20081102055156|18016478, 500 records retrieved.
# Search with continue index: 20081103082853|18034684, 500 records retrieved.
# Search with continue index: 20081103233310|18046725, 500 records retrieved.
# Search with continue index: 20081104185055|18060739, 500 records retrieved.
# Search with continue index: 20081105162603|18076457, 500 records retrieved.
# Search with continue index: 20081106060133|18087257, 500 records retrieved.
# Search with continue index: 20081107001936|18101175, 500 records retrieved.
# Search with continue index: 20081107184730|18115191, 500 records retrieved.
# Search with continue index: 20081108212218|18132436, 500 records retrieved.
# Search with continue index: 20081109232645|18152858, 500 records retrieved.
# Search with continue index: 20081110200720|18175014, 500 records retrieved.
# Search with continue index: 20081111154024|18190493, 500 records retrieved.
# Search with continue index: 20081112095453|18206218, 500 records retrieved.
# Search with continue index: 20081112232557|18217811, 500 records retrieved.
# Search with continue index: 20081113135028|18227282, 500 records retrieved.
# Search with continue index: 20081114030254|18238637, 500 records retrieved.
# Search with continue index: 20081114225116|18252223, 500 records retrieved.
# Search with continue index: 20081115031516|18255727, 500 records retrieved.
# Search with continue index: 20081115032821|18256348, 500 records retrieved.
# Search with continue index: 20081115034131|18256966, 500 records retrieved.
# Search with continue index: 20081115035446|18257623, 500 records retrieved.
# Search with continue index: 20081115074334|18260054, 500 records retrieved.
# Search with continue index: 20081116193110|18287432, 500 records retrieved.
# Search with continue index: 20081117204618|18311622, 500 records retrieved.
# Search with continue index: 20081118164809|18329252, 500 records retrieved.
# Search with continue index: 20081119120200|18346825, 500 records retrieved.
# Search with continue index: 20081120013353|18359927, 500 records retrieved.
# Search with continue index: 20081120211520|18373664, 500 records retrieved.
# Search with continue index: 20081121200307|18394033, 500 records retrieved.
# Search with continue index: 20081123063709|18423301, 500 records retrieved.
# Search with continue index: 20081124114345|18444813, 500 records retrieved.
# Search with continue index: 20081125031240|18461046, 500 records retrieved.
# Search with continue index: 20081125224611|18477768, 500 records retrieved.
# Search with continue index: 20081127025830|18502864, 500 records retrieved.
# Search with continue index: 20081128180458|18536406, 500 records retrieved.
# Search with continue index: 20081130030342|18566465, 268 records retrieved.
# Retrieval complete for logs between 2008-11-01T00:00:00Z and 2008-12-01T00:00:00Z.
# 18268 records retrieved.
# 500 records retrieved.
# Search with continue index: 20081201191240|18601338, 500 records retrieved.
# Search with continue index: 20081202160847|18618590, 500 records retrieved.
# Search with continue index: 20081203102840|18633220, 500 records retrieved.
# Search with continue index: 20081204012225|18646390, 500 records retrieved.
# Search with continue index: 20081205003049|18662508, 500 records retrieved.
# Search with continue index: 20081205211040|18677828, 500 records retrieved.
# Search with continue index: 20081206213956|18693007, 500 records retrieved.
# Search with continue index: 20081207164507|18704520, 500 records retrieved.
# Search with continue index: 20081208135015|18721251, 500 records retrieved.
# Search with continue index: 20081208162125|18724346, 500 records retrieved.
# Search with continue index: 20081209005545|18734012, 500 records retrieved.
# Search with continue index: 20081209130910|18743135, 500 records retrieved.
# Search with continue index: 20081209201837|18749987, 500 records retrieved.
# Search with continue index: 20081210112423|18764267, 500 records retrieved.
# Search with continue index: 20081210202600|18774976, 500 records retrieved.
# Search with continue index: 20081211070904|18785200, 500 records retrieved.
# Search with continue index: 20081211190926|18798013, 500 records retrieved.
# Search with continue index: 20081212082020|18810779, 500 records retrieved.
# Search with continue index: 20081213011756|18828694, 500 records retrieved.
# Search with continue index: 20081214145019|18858234, 500 records retrieved.
# Search with continue index: 20081215194220|18884163, 500 records retrieved.
# Search with continue index: 20081216172847|18905095, 500 records retrieved.
# Search with continue index: 20081217173125|18927417, 500 records retrieved.
# Search with continue index: 20081218184956|18944327, 500 records retrieved.
# Search with continue index: 20081219203749|18964562, 500 records retrieved.
# Search with continue index: 20081221004014|18988486, 500 records retrieved.
# Search with continue index: 20081222084923|19017307, 500 records retrieved.
# Search with continue index: 20081223160717|19047200, 500 records retrieved.
# Search with continue index: 20081224105838|19065789, 500 records retrieved.
# Search with continue index: 20081226094924|19100022, 500 records retrieved.
# Search with continue index: 20081227231512|19118874, 500 records retrieved.
# Search with continue index: 20081229141545|19154432, 500 records retrieved.
# Search with continue index: 20081231004601|19190137, 363 records retrieved.
# Retrieval complete for logs between 2008-12-01T00:00:00Z and 2009-01-01T00:00:00Z.
# 16863 records retrieved.
